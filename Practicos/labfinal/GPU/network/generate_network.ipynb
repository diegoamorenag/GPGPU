# %%
def generate_median_network(n):
    def compare_exchange(i, j):
        return f"PIX_SORT(p[{i}], p[{j}]);"

    def bitonic_merge(low, cnt, ascending):
        if cnt > 1:
            k = cnt // 2
            for i in range(low, low + k):
                if ascending == (i % 2 == 0):
                    yield compare_exchange(i, i + k)
            yield from bitonic_merge(low, k, ascending)
            yield from bitonic_merge(low + k, k, ascending)

    def bitonic_sort(low, cnt, ascending):
        if cnt > 1:
            k = cnt // 2
            yield from bitonic_sort(low, k, True)
            yield from bitonic_sort(low + k, k, False)
            yield from bitonic_merge(low, cnt, ascending)

    return list(bitonic_sort(0, n, True))

def print_cuda_median_network(n):
    network = generate_median_network(n)
    print("typedef unsigned char pixelvalue;")
    print("#define PIX_SORT(a,b) { if ((a)>(b)) PIX_SWAP((a),(b)); }")
    print("#define PIX_SWAP(a,b) { pixelvalue temp=(a);(a)=(b);(b)=temp; }")
    print()
    print(f"__device__ pixelvalue opt_med{n}(pixelvalue * p) {{")
    
    # Group comparisons into lines of 3 (or less for the last line)
    for i in range(0, len(network), 3):
        line = " ".join(network[i:i+3])
        print(f"    {line}")
    
    # Add return statement
    if n % 2 == 0:
        print(f"    return (p[{n//2 - 1}] + p[{n//2}]) / 2;")
    else:
        print(f"    return p[{n//2}];")
    
    print("}")

# Example usage
print_cuda_median_network(49)
# Out:
# typedef unsigned char pixelvalue;
# #define PIX_SORT(a,b) { if ((a)>(b)) PIX_SWAP((a),(b)); }
# #define PIX_SWAP(a,b) { pixelvalue temp=(a);(a)=(b);(b)=temp; }
#
# __device__ pixelvalue opt_med49(pixelvalue * p) {
#     PIX_SORT(p[0], p[1]); PIX_SORT(p[3], p[4]); PIX_SORT(p[0], p[3]);
#     PIX_SORT(p[2], p[5]); PIX_SORT(p[0], p[1]); PIX_SORT(p[6], p[7]);
#     PIX_SORT(p[9], p[10]); PIX_SORT(p[7], p[10]); PIX_SORT(p[9], p[10]);
#     PIX_SORT(p[0], p[6]); PIX_SORT(p[2], p[8]); PIX_SORT(p[4], p[10]);
#     PIX_SORT(p[0], p[3]); PIX_SORT(p[2], p[5]); PIX_SORT(p[0], p[1]);
#     PIX_SORT(p[6], p[9]); PIX_SORT(p[8], p[11]); PIX_SORT(p[6], p[7]);
#     PIX_SORT(p[12], p[13]); PIX_SORT(p[15], p[16]); PIX_SORT(p[12], p[15]);
#     PIX_SORT(p[14], p[17]); PIX_SORT(p[12], p[13]); PIX_SORT(p[18], p[19]);
#     PIX_SORT(p[21], p[22]); PIX_SORT(p[19], p[22]); PIX_SORT(p[21], p[22]);
#     PIX_SORT(p[13], p[19]); PIX_SORT(p[15], p[21]); PIX_SORT(p[17], p[23]);
#     PIX_SORT(p[13], p[16]); PIX_SORT(p[15], p[16]); PIX_SORT(p[19], p[22]);
#     PIX_SORT(p[21], p[22]); PIX_SORT(p[0], p[12]); PIX_SORT(p[2], p[14]);
#     PIX_SORT(p[4], p[16]); PIX_SORT(p[6], p[18]); PIX_SORT(p[8], p[20]);
#     PIX_SORT(p[10], p[22]); PIX_SORT(p[0], p[6]); PIX_SORT(p[2], p[8]);
#     PIX_SORT(p[4], p[10]); PIX_SORT(p[0], p[3]); PIX_SORT(p[2], p[5]);
#     PIX_SORT(p[0], p[1]); PIX_SORT(p[6], p[9]); PIX_SORT(p[8], p[11]);
#     PIX_SORT(p[6], p[7]); PIX_SORT(p[12], p[18]); PIX_SORT(p[14], p[20]);
#     PIX_SORT(p[16], p[22]); PIX_SORT(p[12], p[15]); PIX_SORT(p[14], p[17]);
#     PIX_SORT(p[12], p[13]); PIX_SORT(p[18], p[21]); PIX_SORT(p[20], p[23]);
#     PIX_SORT(p[18], p[19]); PIX_SORT(p[24], p[25]); PIX_SORT(p[27], p[28]);
#     PIX_SORT(p[24], p[27]); PIX_SORT(p[26], p[29]); PIX_SORT(p[24], p[25]);
#     PIX_SORT(p[30], p[31]); PIX_SORT(p[33], p[34]); PIX_SORT(p[31], p[34]);
#     PIX_SORT(p[33], p[34]); PIX_SORT(p[24], p[30]); PIX_SORT(p[26], p[32]);
#     PIX_SORT(p[28], p[34]); PIX_SORT(p[24], p[27]); PIX_SORT(p[26], p[29]);
#     PIX_SORT(p[24], p[25]); PIX_SORT(p[30], p[33]); PIX_SORT(p[32], p[35]);
#     PIX_SORT(p[30], p[31]); PIX_SORT(p[36], p[37]); PIX_SORT(p[39], p[40]);
#     PIX_SORT(p[36], p[39]); PIX_SORT(p[38], p[41]); PIX_SORT(p[36], p[37]);
#     PIX_SORT(p[42], p[43]); PIX_SORT(p[45], p[46]); PIX_SORT(p[43], p[46]);
#     PIX_SORT(p[45], p[46]); PIX_SORT(p[37], p[43]); PIX_SORT(p[39], p[45]);
#     PIX_SORT(p[41], p[47]); PIX_SORT(p[37], p[40]); PIX_SORT(p[39], p[40]);
#     PIX_SORT(p[43], p[46]); PIX_SORT(p[45], p[46]); PIX_SORT(p[25], p[37]);
#     PIX_SORT(p[27], p[39]); PIX_SORT(p[29], p[41]); PIX_SORT(p[31], p[43]);
#     PIX_SORT(p[33], p[45]); PIX_SORT(p[35], p[47]); PIX_SORT(p[25], p[31]);
#     PIX_SORT(p[27], p[33]); PIX_SORT(p[29], p[35]); PIX_SORT(p[25], p[28]);
#     PIX_SORT(p[27], p[28]); PIX_SORT(p[31], p[34]); PIX_SORT(p[33], p[34]);
#     PIX_SORT(p[37], p[43]); PIX_SORT(p[39], p[45]); PIX_SORT(p[41], p[47]);
#     PIX_SORT(p[37], p[40]); PIX_SORT(p[39], p[40]); PIX_SORT(p[43], p[46]);
#     PIX_SORT(p[45], p[46]); PIX_SORT(p[0], p[24]); PIX_SORT(p[2], p[26]);
#     PIX_SORT(p[4], p[28]); PIX_SORT(p[6], p[30]); PIX_SORT(p[8], p[32]);
#     PIX_SORT(p[10], p[34]); PIX_SORT(p[12], p[36]); PIX_SORT(p[14], p[38]);
#     PIX_SORT(p[16], p[40]); PIX_SORT(p[18], p[42]); PIX_SORT(p[20], p[44]);
#     PIX_SORT(p[22], p[46]); PIX_SORT(p[0], p[12]); PIX_SORT(p[2], p[14]);
#     PIX_SORT(p[4], p[16]); PIX_SORT(p[6], p[18]); PIX_SORT(p[8], p[20]);
#     PIX_SORT(p[10], p[22]); PIX_SORT(p[0], p[6]); PIX_SORT(p[2], p[8]);
#     PIX_SORT(p[4], p[10]); PIX_SORT(p[0], p[3]); PIX_SORT(p[2], p[5]);
#     PIX_SORT(p[0], p[1]); PIX_SORT(p[6], p[9]); PIX_SORT(p[8], p[11]);
#     PIX_SORT(p[6], p[7]); PIX_SORT(p[12], p[18]); PIX_SORT(p[14], p[20]);
#     PIX_SORT(p[16], p[22]); PIX_SORT(p[12], p[15]); PIX_SORT(p[14], p[17]);
#     PIX_SORT(p[12], p[13]); PIX_SORT(p[18], p[21]); PIX_SORT(p[20], p[23]);
#     PIX_SORT(p[18], p[19]); PIX_SORT(p[24], p[36]); PIX_SORT(p[26], p[38]);
#     PIX_SORT(p[28], p[40]); PIX_SORT(p[30], p[42]); PIX_SORT(p[32], p[44]);
#     PIX_SORT(p[34], p[46]); PIX_SORT(p[24], p[30]); PIX_SORT(p[26], p[32]);
#     PIX_SORT(p[28], p[34]); PIX_SORT(p[24], p[27]); PIX_SORT(p[26], p[29]);
#     PIX_SORT(p[24], p[25]); PIX_SORT(p[30], p[33]); PIX_SORT(p[32], p[35]);
#     PIX_SORT(p[30], p[31]); PIX_SORT(p[36], p[42]); PIX_SORT(p[38], p[44]);
#     PIX_SORT(p[40], p[46]); PIX_SORT(p[36], p[39]); PIX_SORT(p[38], p[41]);
#     PIX_SORT(p[36], p[37]); PIX_SORT(p[42], p[45]); PIX_SORT(p[44], p[47]);
#     PIX_SORT(p[42], p[43]);
#     return p[24];
# }

# %%
import random

def generate_median_network(n):
    def compare_exchange(i, j):
        return f"PIX_SORT(p[{i}], p[{j}]);"

    network = []
    for i in range(n):
        for j in range(i + 1, n):
            network.append((i, j))
    
    return network

def print_cuda_median_network(n):
    network = generate_median_network(n)
    print("typedef unsigned char pixelvalue;")
    print("#define PIX_SORT(a,b) { if ((a)>(b)) PIX_SWAP((a),(b)); }")
    print("#define PIX_SWAP(a,b) { pixelvalue temp=(a);(a)=(b);(b)=temp; }")
    print()
    print(f"__device__ pixelvalue opt_med{n}(pixelvalue * p) {{")
    
    # Group comparisons into lines of 3 (or less for the last line)
    for i in range(0, len(network), 3):
        line = " ".join(f"PIX_SORT(p[{a}], p[{b}]);" for a, b in network[i:i+3])
        print(f"    {line}")
    
    # Add return statement
    if n % 2 == 0:
        print(f"    return (p[{n//2 - 1}] + p[{n//2}]) / 2;")
    else:
        print(f"    return p[{n//2}];")
    
    print("}")

def test_median_network(n, num_tests=1000):
    network = generate_median_network(n)
    
    def apply_network(arr):
        for i, j in network:
            if arr[i] > arr[j]:
                arr[i], arr[j] = arr[j], arr[i]
        return arr[n//2] if n % 2 != 0 else (arr[n//2 - 1] + arr[n//2]) // 2

    for _ in range(num_tests):
        test_array = [random.randint(0, 255) for _ in range(n)]
        network_result = apply_network(test_array.copy())
        true_median = sorted(test_array)[n//2]
        
        if network_result != true_median:
            print(f"Test failed for input: {test_array}")
            print(f"Network result: {network_result}")
            print(f"True median: {true_median}")
            return False

    print(f"All {num_tests} tests passed for n={n}")
    return True

# Test the network generator
test_median_network(81)

# Example usage
print_cuda_median_network(81)
# Out:
# All 1000 tests passed for n=81
# typedef unsigned char pixelvalue;
# #define PIX_SORT(a,b) { if ((a)>(b)) PIX_SWAP((a),(b)); }
# #define PIX_SWAP(a,b) { pixelvalue temp=(a);(a)=(b);(b)=temp; }
#
# __device__ pixelvalue opt_med81(pixelvalue * p) {
#     PIX_SORT(p[0], p[1]); PIX_SORT(p[0], p[2]); PIX_SORT(p[0], p[3]);
#     PIX_SORT(p[0], p[4]); PIX_SORT(p[0], p[5]); PIX_SORT(p[0], p[6]);
#     PIX_SORT(p[0], p[7]); PIX_SORT(p[0], p[8]); PIX_SORT(p[0], p[9]);
#     PIX_SORT(p[0], p[10]); PIX_SORT(p[0], p[11]); PIX_SORT(p[0], p[12]);
#     PIX_SORT(p[0], p[13]); PIX_SORT(p[0], p[14]); PIX_SORT(p[0], p[15]);
#     PIX_SORT(p[0], p[16]); PIX_SORT(p[0], p[17]); PIX_SORT(p[0], p[18]);
#     PIX_SORT(p[0], p[19]); PIX_SORT(p[0], p[20]); PIX_SORT(p[0], p[21]);
#     PIX_SORT(p[0], p[22]); PIX_SORT(p[0], p[23]); PIX_SORT(p[0], p[24]);
#     PIX_SORT(p[0], p[25]); PIX_SORT(p[0], p[26]); PIX_SORT(p[0], p[27]);
#     PIX_SORT(p[0], p[28]); PIX_SORT(p[0], p[29]); PIX_SORT(p[0], p[30]);
#     PIX_SORT(p[0], p[31]); PIX_SORT(p[0], p[32]); PIX_SORT(p[0], p[33]);
#     PIX_SORT(p[0], p[34]); PIX_SORT(p[0], p[35]); PIX_SORT(p[0], p[36]);
#     PIX_SORT(p[0], p[37]); PIX_SORT(p[0], p[38]); PIX_SORT(p[0], p[39]);
#     PIX_SORT(p[0], p[40]); PIX_SORT(p[0], p[41]); PIX_SORT(p[0], p[42]);
#     PIX_SORT(p[0], p[43]); PIX_SORT(p[0], p[44]); PIX_SORT(p[0], p[45]);
#     PIX_SORT(p[0], p[46]); PIX_SORT(p[0], p[47]); PIX_SORT(p[0], p[48]);
#     PIX_SORT(p[0], p[49]); PIX_SORT(p[0], p[50]); PIX_SORT(p[0], p[51]);
#     PIX_SORT(p[0], p[52]); PIX_SORT(p[0], p[53]); PIX_SORT(p[0], p[54]);
#     PIX_SORT(p[0], p[55]); PIX_SORT(p[0], p[56]); PIX_SORT(p[0], p[57]);
#     PIX_SORT(p[0], p[58]); PIX_SORT(p[0], p[59]); PIX_SORT(p[0], p[60]);
#     PIX_SORT(p[0], p[61]); PIX_SORT(p[0], p[62]); PIX_SORT(p[0], p[63]);
#     PIX_SORT(p[0], p[64]); PIX_SORT(p[0], p[65]); PIX_SORT(p[0], p[66]);
#     PIX_SORT(p[0], p[67]); PIX_SORT(p[0], p[68]); PIX_SORT(p[0], p[69]);
#     PIX_SORT(p[0], p[70]); PIX_SORT(p[0], p[71]); PIX_SORT(p[0], p[72]);
#     PIX_SORT(p[0], p[73]); PIX_SORT(p[0], p[74]); PIX_SORT(p[0], p[75]);
#     PIX_SORT(p[0], p[76]); PIX_SORT(p[0], p[77]); PIX_SORT(p[0], p[78]);
#     PIX_SORT(p[0], p[79]); PIX_SORT(p[0], p[80]); PIX_SORT(p[1], p[2]);
#     PIX_SORT(p[1], p[3]); PIX_SORT(p[1], p[4]); PIX_SORT(p[1], p[5]);
#     PIX_SORT(p[1], p[6]); PIX_SORT(p[1], p[7]); PIX_SORT(p[1], p[8]);
#     PIX_SORT(p[1], p[9]); PIX_SORT(p[1], p[10]); PIX_SORT(p[1], p[11]);
#     PIX_SORT(p[1], p[12]); PIX_SORT(p[1], p[13]); PIX_SORT(p[1], p[14]);
#     PIX_SORT(p[1], p[15]); PIX_SORT(p[1], p[16]); PIX_SORT(p[1], p[17]);
#     PIX_SORT(p[1], p[18]); PIX_SORT(p[1], p[19]); PIX_SORT(p[1], p[20]);
#     PIX_SORT(p[1], p[21]); PIX_SORT(p[1], p[22]); PIX_SORT(p[1], p[23]);
#     PIX_SORT(p[1], p[24]); PIX_SORT(p[1], p[25]); PIX_SORT(p[1], p[26]);
#     PIX_SORT(p[1], p[27]); PIX_SORT(p[1], p[28]); PIX_SORT(p[1], p[29]);
#     PIX_SORT(p[1], p[30]); PIX_SORT(p[1], p[31]); PIX_SORT(p[1], p[32]);
#     PIX_SORT(p[1], p[33]); PIX_SORT(p[1], p[34]); PIX_SORT(p[1], p[35]);
#     PIX_SORT(p[1], p[36]); PIX_SORT(p[1], p[37]); PIX_SORT(p[1], p[38]);
#     PIX_SORT(p[1], p[39]); PIX_SORT(p[1], p[40]); PIX_SORT(p[1], p[41]);
#     PIX_SORT(p[1], p[42]); PIX_SORT(p[1], p[43]); PIX_SORT(p[1], p[44]);
#     PIX_SORT(p[1], p[45]); PIX_SORT(p[1], p[46]); PIX_SORT(p[1], p[47]);
#     PIX_SORT(p[1], p[48]); PIX_SORT(p[1], p[49]); PIX_SORT(p[1], p[50]);
#     PIX_SORT(p[1], p[51]); PIX_SORT(p[1], p[52]); PIX_SORT(p[1], p[53]);
#     PIX_SORT(p[1], p[54]); PIX_SORT(p[1], p[55]); PIX_SORT(p[1], p[56]);
#     PIX_SORT(p[1], p[57]); PIX_SORT(p[1], p[58]); PIX_SORT(p[1], p[59]);
#     PIX_SORT(p[1], p[60]); PIX_SORT(p[1], p[61]); PIX_SORT(p[1], p[62]);
#     PIX_SORT(p[1], p[63]); PIX_SORT(p[1], p[64]); PIX_SORT(p[1], p[65]);
#     PIX_SORT(p[1], p[66]); PIX_SORT(p[1], p[67]); PIX_SORT(p[1], p[68]);
#     PIX_SORT(p[1], p[69]); PIX_SORT(p[1], p[70]); PIX_SORT(p[1], p[71]);
#     PIX_SORT(p[1], p[72]); PIX_SORT(p[1], p[73]); PIX_SORT(p[1], p[74]);
#     PIX_SORT(p[1], p[75]); PIX_SORT(p[1], p[76]); PIX_SORT(p[1], p[77]);
#     PIX_SORT(p[1], p[78]); PIX_SORT(p[1], p[79]); PIX_SORT(p[1], p[80]);
#     PIX_SORT(p[2], p[3]); PIX_SORT(p[2], p[4]); PIX_SORT(p[2], p[5]);
#     PIX_SORT(p[2], p[6]); PIX_SORT(p[2], p[7]); PIX_SORT(p[2], p[8]);
#     PIX_SORT(p[2], p[9]); PIX_SORT(p[2], p[10]); PIX_SORT(p[2], p[11]);
#     PIX_SORT(p[2], p[12]); PIX_SORT(p[2], p[13]); PIX_SORT(p[2], p[14]);
#     PIX_SORT(p[2], p[15]); PIX_SORT(p[2], p[16]); PIX_SORT(p[2], p[17]);
#     PIX_SORT(p[2], p[18]); PIX_SORT(p[2], p[19]); PIX_SORT(p[2], p[20]);
#     PIX_SORT(p[2], p[21]); PIX_SORT(p[2], p[22]); PIX_SORT(p[2], p[23]);
#     PIX_SORT(p[2], p[24]); PIX_SORT(p[2], p[25]); PIX_SORT(p[2], p[26]);
#     PIX_SORT(p[2], p[27]); PIX_SORT(p[2], p[28]); PIX_SORT(p[2], p[29]);
#     PIX_SORT(p[2], p[30]); PIX_SORT(p[2], p[31]); PIX_SORT(p[2], p[32]);
#     PIX_SORT(p[2], p[33]); PIX_SORT(p[2], p[34]); PIX_SORT(p[2], p[35]);
#     PIX_SORT(p[2], p[36]); PIX_SORT(p[2], p[37]); PIX_SORT(p[2], p[38]);
#     PIX_SORT(p[2], p[39]); PIX_SORT(p[2], p[40]); PIX_SORT(p[2], p[41]);
#     PIX_SORT(p[2], p[42]); PIX_SORT(p[2], p[43]); PIX_SORT(p[2], p[44]);
#     PIX_SORT(p[2], p[45]); PIX_SORT(p[2], p[46]); PIX_SORT(p[2], p[47]);
#     PIX_SORT(p[2], p[48]); PIX_SORT(p[2], p[49]); PIX_SORT(p[2], p[50]);
#     PIX_SORT(p[2], p[51]); PIX_SORT(p[2], p[52]); PIX_SORT(p[2], p[53]);
#     PIX_SORT(p[2], p[54]); PIX_SORT(p[2], p[55]); PIX_SORT(p[2], p[56]);
#     PIX_SORT(p[2], p[57]); PIX_SORT(p[2], p[58]); PIX_SORT(p[2], p[59]);
#     PIX_SORT(p[2], p[60]); PIX_SORT(p[2], p[61]); PIX_SORT(p[2], p[62]);
#     PIX_SORT(p[2], p[63]); PIX_SORT(p[2], p[64]); PIX_SORT(p[2], p[65]);
#     PIX_SORT(p[2], p[66]); PIX_SORT(p[2], p[67]); PIX_SORT(p[2], p[68]);
#     PIX_SORT(p[2], p[69]); PIX_SORT(p[2], p[70]); PIX_SORT(p[2], p[71]);
#     PIX_SORT(p[2], p[72]); PIX_SORT(p[2], p[73]); PIX_SORT(p[2], p[74]);
#     PIX_SORT(p[2], p[75]); PIX_SORT(p[2], p[76]); PIX_SORT(p[2], p[77]);
#     PIX_SORT(p[2], p[78]); PIX_SORT(p[2], p[79]); PIX_SORT(p[2], p[80]);
#     PIX_SORT(p[3], p[4]); PIX_SORT(p[3], p[5]); PIX_SORT(p[3], p[6]);
#     PIX_SORT(p[3], p[7]); PIX_SORT(p[3], p[8]); PIX_SORT(p[3], p[9]);
#     PIX_SORT(p[3], p[10]); PIX_SORT(p[3], p[11]); PIX_SORT(p[3], p[12]);
#     PIX_SORT(p[3], p[13]); PIX_SORT(p[3], p[14]); PIX_SORT(p[3], p[15]);
#     PIX_SORT(p[3], p[16]); PIX_SORT(p[3], p[17]); PIX_SORT(p[3], p[18]);
#     PIX_SORT(p[3], p[19]); PIX_SORT(p[3], p[20]); PIX_SORT(p[3], p[21]);
#     PIX_SORT(p[3], p[22]); PIX_SORT(p[3], p[23]); PIX_SORT(p[3], p[24]);
#     PIX_SORT(p[3], p[25]); PIX_SORT(p[3], p[26]); PIX_SORT(p[3], p[27]);
#     PIX_SORT(p[3], p[28]); PIX_SORT(p[3], p[29]); PIX_SORT(p[3], p[30]);
#     PIX_SORT(p[3], p[31]); PIX_SORT(p[3], p[32]); PIX_SORT(p[3], p[33]);
#     PIX_SORT(p[3], p[34]); PIX_SORT(p[3], p[35]); PIX_SORT(p[3], p[36]);
#     PIX_SORT(p[3], p[37]); PIX_SORT(p[3], p[38]); PIX_SORT(p[3], p[39]);
#     PIX_SORT(p[3], p[40]); PIX_SORT(p[3], p[41]); PIX_SORT(p[3], p[42]);
#     PIX_SORT(p[3], p[43]); PIX_SORT(p[3], p[44]); PIX_SORT(p[3], p[45]);
#     PIX_SORT(p[3], p[46]); PIX_SORT(p[3], p[47]); PIX_SORT(p[3], p[48]);
#     PIX_SORT(p[3], p[49]); PIX_SORT(p[3], p[50]); PIX_SORT(p[3], p[51]);
#     PIX_SORT(p[3], p[52]); PIX_SORT(p[3], p[53]); PIX_SORT(p[3], p[54]);
#     PIX_SORT(p[3], p[55]); PIX_SORT(p[3], p[56]); PIX_SORT(p[3], p[57]);
#     PIX_SORT(p[3], p[58]); PIX_SORT(p[3], p[59]); PIX_SORT(p[3], p[60]);
#     PIX_SORT(p[3], p[61]); PIX_SORT(p[3], p[62]); PIX_SORT(p[3], p[63]);
#     PIX_SORT(p[3], p[64]); PIX_SORT(p[3], p[65]); PIX_SORT(p[3], p[66]);
#     PIX_SORT(p[3], p[67]); PIX_SORT(p[3], p[68]); PIX_SORT(p[3], p[69]);
#     PIX_SORT(p[3], p[70]); PIX_SORT(p[3], p[71]); PIX_SORT(p[3], p[72]);
#     PIX_SORT(p[3], p[73]); PIX_SORT(p[3], p[74]); PIX_SORT(p[3], p[75]);
#     PIX_SORT(p[3], p[76]); PIX_SORT(p[3], p[77]); PIX_SORT(p[3], p[78]);
#     PIX_SORT(p[3], p[79]); PIX_SORT(p[3], p[80]); PIX_SORT(p[4], p[5]);
#     PIX_SORT(p[4], p[6]); PIX_SORT(p[4], p[7]); PIX_SORT(p[4], p[8]);
#     PIX_SORT(p[4], p[9]); PIX_SORT(p[4], p[10]); PIX_SORT(p[4], p[11]);
#     PIX_SORT(p[4], p[12]); PIX_SORT(p[4], p[13]); PIX_SORT(p[4], p[14]);
#     PIX_SORT(p[4], p[15]); PIX_SORT(p[4], p[16]); PIX_SORT(p[4], p[17]);
#     PIX_SORT(p[4], p[18]); PIX_SORT(p[4], p[19]); PIX_SORT(p[4], p[20]);
#     PIX_SORT(p[4], p[21]); PIX_SORT(p[4], p[22]); PIX_SORT(p[4], p[23]);
#     PIX_SORT(p[4], p[24]); PIX_SORT(p[4], p[25]); PIX_SORT(p[4], p[26]);
#     PIX_SORT(p[4], p[27]); PIX_SORT(p[4], p[28]); PIX_SORT(p[4], p[29]);
#     PIX_SORT(p[4], p[30]); PIX_SORT(p[4], p[31]); PIX_SORT(p[4], p[32]);
#     PIX_SORT(p[4], p[33]); PIX_SORT(p[4], p[34]); PIX_SORT(p[4], p[35]);
#     PIX_SORT(p[4], p[36]); PIX_SORT(p[4], p[37]); PIX_SORT(p[4], p[38]);
#     PIX_SORT(p[4], p[39]); PIX_SORT(p[4], p[40]); PIX_SORT(p[4], p[41]);
#     PIX_SORT(p[4], p[42]); PIX_SORT(p[4], p[43]); PIX_SORT(p[4], p[44]);
#     PIX_SORT(p[4], p[45]); PIX_SORT(p[4], p[46]); PIX_SORT(p[4], p[47]);
#     PIX_SORT(p[4], p[48]); PIX_SORT(p[4], p[49]); PIX_SORT(p[4], p[50]);
#     PIX_SORT(p[4], p[51]); PIX_SORT(p[4], p[52]); PIX_SORT(p[4], p[53]);
#     PIX_SORT(p[4], p[54]); PIX_SORT(p[4], p[55]); PIX_SORT(p[4], p[56]);
#     PIX_SORT(p[4], p[57]); PIX_SORT(p[4], p[58]); PIX_SORT(p[4], p[59]);
#     PIX_SORT(p[4], p[60]); PIX_SORT(p[4], p[61]); PIX_SORT(p[4], p[62]);
#     PIX_SORT(p[4], p[63]); PIX_SORT(p[4], p[64]); PIX_SORT(p[4], p[65]);
#     PIX_SORT(p[4], p[66]); PIX_SORT(p[4], p[67]); PIX_SORT(p[4], p[68]);
#     PIX_SORT(p[4], p[69]); PIX_SORT(p[4], p[70]); PIX_SORT(p[4], p[71]);
#     PIX_SORT(p[4], p[72]); PIX_SORT(p[4], p[73]); PIX_SORT(p[4], p[74]);
#     PIX_SORT(p[4], p[75]); PIX_SORT(p[4], p[76]); PIX_SORT(p[4], p[77]);
#     PIX_SORT(p[4], p[78]); PIX_SORT(p[4], p[79]); PIX_SORT(p[4], p[80]);
#     PIX_SORT(p[5], p[6]); PIX_SORT(p[5], p[7]); PIX_SORT(p[5], p[8]);
#     PIX_SORT(p[5], p[9]); PIX_SORT(p[5], p[10]); PIX_SORT(p[5], p[11]);
#     PIX_SORT(p[5], p[12]); PIX_SORT(p[5], p[13]); PIX_SORT(p[5], p[14]);
#     PIX_SORT(p[5], p[15]); PIX_SORT(p[5], p[16]); PIX_SORT(p[5], p[17]);
#     PIX_SORT(p[5], p[18]); PIX_SORT(p[5], p[19]); PIX_SORT(p[5], p[20]);
#     PIX_SORT(p[5], p[21]); PIX_SORT(p[5], p[22]); PIX_SORT(p[5], p[23]);
#     PIX_SORT(p[5], p[24]); PIX_SORT(p[5], p[25]); PIX_SORT(p[5], p[26]);
#     PIX_SORT(p[5], p[27]); PIX_SORT(p[5], p[28]); PIX_SORT(p[5], p[29]);
#     PIX_SORT(p[5], p[30]); PIX_SORT(p[5], p[31]); PIX_SORT(p[5], p[32]);
#     PIX_SORT(p[5], p[33]); PIX_SORT(p[5], p[34]); PIX_SORT(p[5], p[35]);
#     PIX_SORT(p[5], p[36]); PIX_SORT(p[5], p[37]); PIX_SORT(p[5], p[38]);
#     PIX_SORT(p[5], p[39]); PIX_SORT(p[5], p[40]); PIX_SORT(p[5], p[41]);
#     PIX_SORT(p[5], p[42]); PIX_SORT(p[5], p[43]); PIX_SORT(p[5], p[44]);
#     PIX_SORT(p[5], p[45]); PIX_SORT(p[5], p[46]); PIX_SORT(p[5], p[47]);
#     PIX_SORT(p[5], p[48]); PIX_SORT(p[5], p[49]); PIX_SORT(p[5], p[50]);
#     PIX_SORT(p[5], p[51]); PIX_SORT(p[5], p[52]); PIX_SORT(p[5], p[53]);
#     PIX_SORT(p[5], p[54]); PIX_SORT(p[5], p[55]); PIX_SORT(p[5], p[56]);
#     PIX_SORT(p[5], p[57]); PIX_SORT(p[5], p[58]); PIX_SORT(p[5], p[59]);
#     PIX_SORT(p[5], p[60]); PIX_SORT(p[5], p[61]); PIX_SORT(p[5], p[62]);
#     PIX_SORT(p[5], p[63]); PIX_SORT(p[5], p[64]); PIX_SORT(p[5], p[65]);
#     PIX_SORT(p[5], p[66]); PIX_SORT(p[5], p[67]); PIX_SORT(p[5], p[68]);
#     PIX_SORT(p[5], p[69]); PIX_SORT(p[5], p[70]); PIX_SORT(p[5], p[71]);
#     PIX_SORT(p[5], p[72]); PIX_SORT(p[5], p[73]); PIX_SORT(p[5], p[74]);
#     PIX_SORT(p[5], p[75]); PIX_SORT(p[5], p[76]); PIX_SORT(p[5], p[77]);
#     PIX_SORT(p[5], p[78]); PIX_SORT(p[5], p[79]); PIX_SORT(p[5], p[80]);
#     PIX_SORT(p[6], p[7]); PIX_SORT(p[6], p[8]); PIX_SORT(p[6], p[9]);
#     PIX_SORT(p[6], p[10]); PIX_SORT(p[6], p[11]); PIX_SORT(p[6], p[12]);
#     PIX_SORT(p[6], p[13]); PIX_SORT(p[6], p[14]); PIX_SORT(p[6], p[15]);
#     PIX_SORT(p[6], p[16]); PIX_SORT(p[6], p[17]); PIX_SORT(p[6], p[18]);
#     PIX_SORT(p[6], p[19]); PIX_SORT(p[6], p[20]); PIX_SORT(p[6], p[21]);
#     PIX_SORT(p[6], p[22]); PIX_SORT(p[6], p[23]); PIX_SORT(p[6], p[24]);
#     PIX_SORT(p[6], p[25]); PIX_SORT(p[6], p[26]); PIX_SORT(p[6], p[27]);
#     PIX_SORT(p[6], p[28]); PIX_SORT(p[6], p[29]); PIX_SORT(p[6], p[30]);
#     PIX_SORT(p[6], p[31]); PIX_SORT(p[6], p[32]); PIX_SORT(p[6], p[33]);
#     PIX_SORT(p[6], p[34]); PIX_SORT(p[6], p[35]); PIX_SORT(p[6], p[36]);
#     PIX_SORT(p[6], p[37]); PIX_SORT(p[6], p[38]); PIX_SORT(p[6], p[39]);
#     PIX_SORT(p[6], p[40]); PIX_SORT(p[6], p[41]); PIX_SORT(p[6], p[42]);
#     PIX_SORT(p[6], p[43]); PIX_SORT(p[6], p[44]); PIX_SORT(p[6], p[45]);
#     PIX_SORT(p[6], p[46]); PIX_SORT(p[6], p[47]); PIX_SORT(p[6], p[48]);
#     PIX_SORT(p[6], p[49]); PIX_SORT(p[6], p[50]); PIX_SORT(p[6], p[51]);
#     PIX_SORT(p[6], p[52]); PIX_SORT(p[6], p[53]); PIX_SORT(p[6], p[54]);
#     PIX_SORT(p[6], p[55]); PIX_SORT(p[6], p[56]); PIX_SORT(p[6], p[57]);
#     PIX_SORT(p[6], p[58]); PIX_SORT(p[6], p[59]); PIX_SORT(p[6], p[60]);
#     PIX_SORT(p[6], p[61]); PIX_SORT(p[6], p[62]); PIX_SORT(p[6], p[63]);
#     PIX_SORT(p[6], p[64]); PIX_SORT(p[6], p[65]); PIX_SORT(p[6], p[66]);
#     PIX_SORT(p[6], p[67]); PIX_SORT(p[6], p[68]); PIX_SORT(p[6], p[69]);
#     PIX_SORT(p[6], p[70]); PIX_SORT(p[6], p[71]); PIX_SORT(p[6], p[72]);
#     PIX_SORT(p[6], p[73]); PIX_SORT(p[6], p[74]); PIX_SORT(p[6], p[75]);
#     PIX_SORT(p[6], p[76]); PIX_SORT(p[6], p[77]); PIX_SORT(p[6], p[78]);
#     PIX_SORT(p[6], p[79]); PIX_SORT(p[6], p[80]); PIX_SORT(p[7], p[8]);
#     PIX_SORT(p[7], p[9]); PIX_SORT(p[7], p[10]); PIX_SORT(p[7], p[11]);
#     PIX_SORT(p[7], p[12]); PIX_SORT(p[7], p[13]); PIX_SORT(p[7], p[14]);
#     PIX_SORT(p[7], p[15]); PIX_SORT(p[7], p[16]); PIX_SORT(p[7], p[17]);
#     PIX_SORT(p[7], p[18]); PIX_SORT(p[7], p[19]); PIX_SORT(p[7], p[20]);
#     PIX_SORT(p[7], p[21]); PIX_SORT(p[7], p[22]); PIX_SORT(p[7], p[23]);
#     PIX_SORT(p[7], p[24]); PIX_SORT(p[7], p[25]); PIX_SORT(p[7], p[26]);
#     PIX_SORT(p[7], p[27]); PIX_SORT(p[7], p[28]); PIX_SORT(p[7], p[29]);
#     PIX_SORT(p[7], p[30]); PIX_SORT(p[7], p[31]); PIX_SORT(p[7], p[32]);
#     PIX_SORT(p[7], p[33]); PIX_SORT(p[7], p[34]); PIX_SORT(p[7], p[35]);
#     PIX_SORT(p[7], p[36]); PIX_SORT(p[7], p[37]); PIX_SORT(p[7], p[38]);
#     PIX_SORT(p[7], p[39]); PIX_SORT(p[7], p[40]); PIX_SORT(p[7], p[41]);
#     PIX_SORT(p[7], p[42]); PIX_SORT(p[7], p[43]); PIX_SORT(p[7], p[44]);
#     PIX_SORT(p[7], p[45]); PIX_SORT(p[7], p[46]); PIX_SORT(p[7], p[47]);
#     PIX_SORT(p[7], p[48]); PIX_SORT(p[7], p[49]); PIX_SORT(p[7], p[50]);
#     PIX_SORT(p[7], p[51]); PIX_SORT(p[7], p[52]); PIX_SORT(p[7], p[53]);
#     PIX_SORT(p[7], p[54]); PIX_SORT(p[7], p[55]); PIX_SORT(p[7], p[56]);
#     PIX_SORT(p[7], p[57]); PIX_SORT(p[7], p[58]); PIX_SORT(p[7], p[59]);
#     PIX_SORT(p[7], p[60]); PIX_SORT(p[7], p[61]); PIX_SORT(p[7], p[62]);
#     PIX_SORT(p[7], p[63]); PIX_SORT(p[7], p[64]); PIX_SORT(p[7], p[65]);
#     PIX_SORT(p[7], p[66]); PIX_SORT(p[7], p[67]); PIX_SORT(p[7], p[68]);
#     PIX_SORT(p[7], p[69]); PIX_SORT(p[7], p[70]); PIX_SORT(p[7], p[71]);
#     PIX_SORT(p[7], p[72]); PIX_SORT(p[7], p[73]); PIX_SORT(p[7], p[74]);
#     PIX_SORT(p[7], p[75]); PIX_SORT(p[7], p[76]); PIX_SORT(p[7], p[77]);
#     PIX_SORT(p[7], p[78]); PIX_SORT(p[7], p[79]); PIX_SORT(p[7], p[80]);
#     PIX_SORT(p[8], p[9]); PIX_SORT(p[8], p[10]); PIX_SORT(p[8], p[11]);
#     PIX_SORT(p[8], p[12]); PIX_SORT(p[8], p[13]); PIX_SORT(p[8], p[14]);
#     PIX_SORT(p[8], p[15]); PIX_SORT(p[8], p[16]); PIX_SORT(p[8], p[17]);
#     PIX_SORT(p[8], p[18]); PIX_SORT(p[8], p[19]); PIX_SORT(p[8], p[20]);
#     PIX_SORT(p[8], p[21]); PIX_SORT(p[8], p[22]); PIX_SORT(p[8], p[23]);
#     PIX_SORT(p[8], p[24]); PIX_SORT(p[8], p[25]); PIX_SORT(p[8], p[26]);
#     PIX_SORT(p[8], p[27]); PIX_SORT(p[8], p[28]); PIX_SORT(p[8], p[29]);
#     PIX_SORT(p[8], p[30]); PIX_SORT(p[8], p[31]); PIX_SORT(p[8], p[32]);
#     PIX_SORT(p[8], p[33]); PIX_SORT(p[8], p[34]); PIX_SORT(p[8], p[35]);
#     PIX_SORT(p[8], p[36]); PIX_SORT(p[8], p[37]); PIX_SORT(p[8], p[38]);
#     PIX_SORT(p[8], p[39]); PIX_SORT(p[8], p[40]); PIX_SORT(p[8], p[41]);
#     PIX_SORT(p[8], p[42]); PIX_SORT(p[8], p[43]); PIX_SORT(p[8], p[44]);
#     PIX_SORT(p[8], p[45]); PIX_SORT(p[8], p[46]); PIX_SORT(p[8], p[47]);
#     PIX_SORT(p[8], p[48]); PIX_SORT(p[8], p[49]); PIX_SORT(p[8], p[50]);
#     PIX_SORT(p[8], p[51]); PIX_SORT(p[8], p[52]); PIX_SORT(p[8], p[53]);
#     PIX_SORT(p[8], p[54]); PIX_SORT(p[8], p[55]); PIX_SORT(p[8], p[56]);
#     PIX_SORT(p[8], p[57]); PIX_SORT(p[8], p[58]); PIX_SORT(p[8], p[59]);
#     PIX_SORT(p[8], p[60]); PIX_SORT(p[8], p[61]); PIX_SORT(p[8], p[62]);
#     PIX_SORT(p[8], p[63]); PIX_SORT(p[8], p[64]); PIX_SORT(p[8], p[65]);
#     PIX_SORT(p[8], p[66]); PIX_SORT(p[8], p[67]); PIX_SORT(p[8], p[68]);
#     PIX_SORT(p[8], p[69]); PIX_SORT(p[8], p[70]); PIX_SORT(p[8], p[71]);
#     PIX_SORT(p[8], p[72]); PIX_SORT(p[8], p[73]); PIX_SORT(p[8], p[74]);
#     PIX_SORT(p[8], p[75]); PIX_SORT(p[8], p[76]); PIX_SORT(p[8], p[77]);
#     PIX_SORT(p[8], p[78]); PIX_SORT(p[8], p[79]); PIX_SORT(p[8], p[80]);
#     PIX_SORT(p[9], p[10]); PIX_SORT(p[9], p[11]); PIX_SORT(p[9], p[12]);
#     PIX_SORT(p[9], p[13]); PIX_SORT(p[9], p[14]); PIX_SORT(p[9], p[15]);
#     PIX_SORT(p[9], p[16]); PIX_SORT(p[9], p[17]); PIX_SORT(p[9], p[18]);
#     PIX_SORT(p[9], p[19]); PIX_SORT(p[9], p[20]); PIX_SORT(p[9], p[21]);
#     PIX_SORT(p[9], p[22]); PIX_SORT(p[9], p[23]); PIX_SORT(p[9], p[24]);
#     PIX_SORT(p[9], p[25]); PIX_SORT(p[9], p[26]); PIX_SORT(p[9], p[27]);
#     PIX_SORT(p[9], p[28]); PIX_SORT(p[9], p[29]); PIX_SORT(p[9], p[30]);
#     PIX_SORT(p[9], p[31]); PIX_SORT(p[9], p[32]); PIX_SORT(p[9], p[33]);
#     PIX_SORT(p[9], p[34]); PIX_SORT(p[9], p[35]); PIX_SORT(p[9], p[36]);
#     PIX_SORT(p[9], p[37]); PIX_SORT(p[9], p[38]); PIX_SORT(p[9], p[39]);
#     PIX_SORT(p[9], p[40]); PIX_SORT(p[9], p[41]); PIX_SORT(p[9], p[42]);
#     PIX_SORT(p[9], p[43]); PIX_SORT(p[9], p[44]); PIX_SORT(p[9], p[45]);
#     PIX_SORT(p[9], p[46]); PIX_SORT(p[9], p[47]); PIX_SORT(p[9], p[48]);
#     PIX_SORT(p[9], p[49]); PIX_SORT(p[9], p[50]); PIX_SORT(p[9], p[51]);
#     PIX_SORT(p[9], p[52]); PIX_SORT(p[9], p[53]); PIX_SORT(p[9], p[54]);
#     PIX_SORT(p[9], p[55]); PIX_SORT(p[9], p[56]); PIX_SORT(p[9], p[57]);
#     PIX_SORT(p[9], p[58]); PIX_SORT(p[9], p[59]); PIX_SORT(p[9], p[60]);
#     PIX_SORT(p[9], p[61]); PIX_SORT(p[9], p[62]); PIX_SORT(p[9], p[63]);
#     PIX_SORT(p[9], p[64]); PIX_SORT(p[9], p[65]); PIX_SORT(p[9], p[66]);
#     PIX_SORT(p[9], p[67]); PIX_SORT(p[9], p[68]); PIX_SORT(p[9], p[69]);
#     PIX_SORT(p[9], p[70]); PIX_SORT(p[9], p[71]); PIX_SORT(p[9], p[72]);
#     PIX_SORT(p[9], p[73]); PIX_SORT(p[9], p[74]); PIX_SORT(p[9], p[75]);
#     PIX_SORT(p[9], p[76]); PIX_SORT(p[9], p[77]); PIX_SORT(p[9], p[78]);
#     PIX_SORT(p[9], p[79]); PIX_SORT(p[9], p[80]); PIX_SORT(p[10], p[11]);
#     PIX_SORT(p[10], p[12]); PIX_SORT(p[10], p[13]); PIX_SORT(p[10], p[14]);
#     PIX_SORT(p[10], p[15]); PIX_SORT(p[10], p[16]); PIX_SORT(p[10], p[17]);
#     PIX_SORT(p[10], p[18]); PIX_SORT(p[10], p[19]); PIX_SORT(p[10], p[20]);
#     PIX_SORT(p[10], p[21]); PIX_SORT(p[10], p[22]); PIX_SORT(p[10], p[23]);
#     PIX_SORT(p[10], p[24]); PIX_SORT(p[10], p[25]); PIX_SORT(p[10], p[26]);
#     PIX_SORT(p[10], p[27]); PIX_SORT(p[10], p[28]); PIX_SORT(p[10], p[29]);
#     PIX_SORT(p[10], p[30]); PIX_SORT(p[10], p[31]); PIX_SORT(p[10], p[32]);
#     PIX_SORT(p[10], p[33]); PIX_SORT(p[10], p[34]); PIX_SORT(p[10], p[35]);
#     PIX_SORT(p[10], p[36]); PIX_SORT(p[10], p[37]); PIX_SORT(p[10], p[38]);
#     PIX_SORT(p[10], p[39]); PIX_SORT(p[10], p[40]); PIX_SORT(p[10], p[41]);
#     PIX_SORT(p[10], p[42]); PIX_SORT(p[10], p[43]); PIX_SORT(p[10], p[44]);
#     PIX_SORT(p[10], p[45]); PIX_SORT(p[10], p[46]); PIX_SORT(p[10], p[47]);
#     PIX_SORT(p[10], p[48]); PIX_SORT(p[10], p[49]); PIX_SORT(p[10], p[50]);
#     PIX_SORT(p[10], p[51]); PIX_SORT(p[10], p[52]); PIX_SORT(p[10], p[53]);
#     PIX_SORT(p[10], p[54]); PIX_SORT(p[10], p[55]); PIX_SORT(p[10], p[56]);
#     PIX_SORT(p[10], p[57]); PIX_SORT(p[10], p[58]); PIX_SORT(p[10], p[59]);
#     PIX_SORT(p[10], p[60]); PIX_SORT(p[10], p[61]); PIX_SORT(p[10], p[62]);
#     PIX_SORT(p[10], p[63]); PIX_SORT(p[10], p[64]); PIX_SORT(p[10], p[65]);
#     PIX_SORT(p[10], p[66]); PIX_SORT(p[10], p[67]); PIX_SORT(p[10], p[68]);
#     PIX_SORT(p[10], p[69]); PIX_SORT(p[10], p[70]); PIX_SORT(p[10], p[71]);
#     PIX_SORT(p[10], p[72]); PIX_SORT(p[10], p[73]); PIX_SORT(p[10], p[74]);
#     PIX_SORT(p[10], p[75]); PIX_SORT(p[10], p[76]); PIX_SORT(p[10], p[77]);
#     PIX_SORT(p[10], p[78]); PIX_SORT(p[10], p[79]); PIX_SORT(p[10], p[80]);
#     PIX_SORT(p[11], p[12]); PIX_SORT(p[11], p[13]); PIX_SORT(p[11], p[14]);
#     PIX_SORT(p[11], p[15]); PIX_SORT(p[11], p[16]); PIX_SORT(p[11], p[17]);
#     PIX_SORT(p[11], p[18]); PIX_SORT(p[11], p[19]); PIX_SORT(p[11], p[20]);
#     PIX_SORT(p[11], p[21]); PIX_SORT(p[11], p[22]); PIX_SORT(p[11], p[23]);
#     PIX_SORT(p[11], p[24]); PIX_SORT(p[11], p[25]); PIX_SORT(p[11], p[26]);
#     PIX_SORT(p[11], p[27]); PIX_SORT(p[11], p[28]); PIX_SORT(p[11], p[29]);
#     PIX_SORT(p[11], p[30]); PIX_SORT(p[11], p[31]); PIX_SORT(p[11], p[32]);
#     PIX_SORT(p[11], p[33]); PIX_SORT(p[11], p[34]); PIX_SORT(p[11], p[35]);
#     PIX_SORT(p[11], p[36]); PIX_SORT(p[11], p[37]); PIX_SORT(p[11], p[38]);
#     PIX_SORT(p[11], p[39]); PIX_SORT(p[11], p[40]); PIX_SORT(p[11], p[41]);
#     PIX_SORT(p[11], p[42]); PIX_SORT(p[11], p[43]); PIX_SORT(p[11], p[44]);
#     PIX_SORT(p[11], p[45]); PIX_SORT(p[11], p[46]); PIX_SORT(p[11], p[47]);
#     PIX_SORT(p[11], p[48]); PIX_SORT(p[11], p[49]); PIX_SORT(p[11], p[50]);
#     PIX_SORT(p[11], p[51]); PIX_SORT(p[11], p[52]); PIX_SORT(p[11], p[53]);
#     PIX_SORT(p[11], p[54]); PIX_SORT(p[11], p[55]); PIX_SORT(p[11], p[56]);
#     PIX_SORT(p[11], p[57]); PIX_SORT(p[11], p[58]); PIX_SORT(p[11], p[59]);
#     PIX_SORT(p[11], p[60]); PIX_SORT(p[11], p[61]); PIX_SORT(p[11], p[62]);
#     PIX_SORT(p[11], p[63]); PIX_SORT(p[11], p[64]); PIX_SORT(p[11], p[65]);
#     PIX_SORT(p[11], p[66]); PIX_SORT(p[11], p[67]); PIX_SORT(p[11], p[68]);
#     PIX_SORT(p[11], p[69]); PIX_SORT(p[11], p[70]); PIX_SORT(p[11], p[71]);
#     PIX_SORT(p[11], p[72]); PIX_SORT(p[11], p[73]); PIX_SORT(p[11], p[74]);
#     PIX_SORT(p[11], p[75]); PIX_SORT(p[11], p[76]); PIX_SORT(p[11], p[77]);
#     PIX_SORT(p[11], p[78]); PIX_SORT(p[11], p[79]); PIX_SORT(p[11], p[80]);
#     PIX_SORT(p[12], p[13]); PIX_SORT(p[12], p[14]); PIX_SORT(p[12], p[15]);
#     PIX_SORT(p[12], p[16]); PIX_SORT(p[12], p[17]); PIX_SORT(p[12], p[18]);
#     PIX_SORT(p[12], p[19]); PIX_SORT(p[12], p[20]); PIX_SORT(p[12], p[21]);
#     PIX_SORT(p[12], p[22]); PIX_SORT(p[12], p[23]); PIX_SORT(p[12], p[24]);
#     PIX_SORT(p[12], p[25]); PIX_SORT(p[12], p[26]); PIX_SORT(p[12], p[27]);
#     PIX_SORT(p[12], p[28]); PIX_SORT(p[12], p[29]); PIX_SORT(p[12], p[30]);
#     PIX_SORT(p[12], p[31]); PIX_SORT(p[12], p[32]); PIX_SORT(p[12], p[33]);
#     PIX_SORT(p[12], p[34]); PIX_SORT(p[12], p[35]); PIX_SORT(p[12], p[36]);
#     PIX_SORT(p[12], p[37]); PIX_SORT(p[12], p[38]); PIX_SORT(p[12], p[39]);
#     PIX_SORT(p[12], p[40]); PIX_SORT(p[12], p[41]); PIX_SORT(p[12], p[42]);
#     PIX_SORT(p[12], p[43]); PIX_SORT(p[12], p[44]); PIX_SORT(p[12], p[45]);
#     PIX_SORT(p[12], p[46]); PIX_SORT(p[12], p[47]); PIX_SORT(p[12], p[48]);
#     PIX_SORT(p[12], p[49]); PIX_SORT(p[12], p[50]); PIX_SORT(p[12], p[51]);
#     PIX_SORT(p[12], p[52]); PIX_SORT(p[12], p[53]); PIX_SORT(p[12], p[54]);
#     PIX_SORT(p[12], p[55]); PIX_SORT(p[12], p[56]); PIX_SORT(p[12], p[57]);
#     PIX_SORT(p[12], p[58]); PIX_SORT(p[12], p[59]); PIX_SORT(p[12], p[60]);
#     PIX_SORT(p[12], p[61]); PIX_SORT(p[12], p[62]); PIX_SORT(p[12], p[63]);
#     PIX_SORT(p[12], p[64]); PIX_SORT(p[12], p[65]); PIX_SORT(p[12], p[66]);
#     PIX_SORT(p[12], p[67]); PIX_SORT(p[12], p[68]); PIX_SORT(p[12], p[69]);
#     PIX_SORT(p[12], p[70]); PIX_SORT(p[12], p[71]); PIX_SORT(p[12], p[72]);
#     PIX_SORT(p[12], p[73]); PIX_SORT(p[12], p[74]); PIX_SORT(p[12], p[75]);
#     PIX_SORT(p[12], p[76]); PIX_SORT(p[12], p[77]); PIX_SORT(p[12], p[78]);
#     PIX_SORT(p[12], p[79]); PIX_SORT(p[12], p[80]); PIX_SORT(p[13], p[14]);
#     PIX_SORT(p[13], p[15]); PIX_SORT(p[13], p[16]); PIX_SORT(p[13], p[17]);
#     PIX_SORT(p[13], p[18]); PIX_SORT(p[13], p[19]); PIX_SORT(p[13], p[20]);
#     PIX_SORT(p[13], p[21]); PIX_SORT(p[13], p[22]); PIX_SORT(p[13], p[23]);
#     PIX_SORT(p[13], p[24]); PIX_SORT(p[13], p[25]); PIX_SORT(p[13], p[26]);
#     PIX_SORT(p[13], p[27]); PIX_SORT(p[13], p[28]); PIX_SORT(p[13], p[29]);
#     PIX_SORT(p[13], p[30]); PIX_SORT(p[13], p[31]); PIX_SORT(p[13], p[32]);
#     PIX_SORT(p[13], p[33]); PIX_SORT(p[13], p[34]); PIX_SORT(p[13], p[35]);
#     PIX_SORT(p[13], p[36]); PIX_SORT(p[13], p[37]); PIX_SORT(p[13], p[38]);
#     PIX_SORT(p[13], p[39]); PIX_SORT(p[13], p[40]); PIX_SORT(p[13], p[41]);
#     PIX_SORT(p[13], p[42]); PIX_SORT(p[13], p[43]); PIX_SORT(p[13], p[44]);
#     PIX_SORT(p[13], p[45]); PIX_SORT(p[13], p[46]); PIX_SORT(p[13], p[47]);
#     PIX_SORT(p[13], p[48]); PIX_SORT(p[13], p[49]); PIX_SORT(p[13], p[50]);
#     PIX_SORT(p[13], p[51]); PIX_SORT(p[13], p[52]); PIX_SORT(p[13], p[53]);
#     PIX_SORT(p[13], p[54]); PIX_SORT(p[13], p[55]); PIX_SORT(p[13], p[56]);
#     PIX_SORT(p[13], p[57]); PIX_SORT(p[13], p[58]); PIX_SORT(p[13], p[59]);
#     PIX_SORT(p[13], p[60]); PIX_SORT(p[13], p[61]); PIX_SORT(p[13], p[62]);
#     PIX_SORT(p[13], p[63]); PIX_SORT(p[13], p[64]); PIX_SORT(p[13], p[65]);
#     PIX_SORT(p[13], p[66]); PIX_SORT(p[13], p[67]); PIX_SORT(p[13], p[68]);
#     PIX_SORT(p[13], p[69]); PIX_SORT(p[13], p[70]); PIX_SORT(p[13], p[71]);
#     PIX_SORT(p[13], p[72]); PIX_SORT(p[13], p[73]); PIX_SORT(p[13], p[74]);
#     PIX_SORT(p[13], p[75]); PIX_SORT(p[13], p[76]); PIX_SORT(p[13], p[77]);
#     PIX_SORT(p[13], p[78]); PIX_SORT(p[13], p[79]); PIX_SORT(p[13], p[80]);
#     PIX_SORT(p[14], p[15]); PIX_SORT(p[14], p[16]); PIX_SORT(p[14], p[17]);
#     PIX_SORT(p[14], p[18]); PIX_SORT(p[14], p[19]); PIX_SORT(p[14], p[20]);
#     PIX_SORT(p[14], p[21]); PIX_SORT(p[14], p[22]); PIX_SORT(p[14], p[23]);
#     PIX_SORT(p[14], p[24]); PIX_SORT(p[14], p[25]); PIX_SORT(p[14], p[26]);
#     PIX_SORT(p[14], p[27]); PIX_SORT(p[14], p[28]); PIX_SORT(p[14], p[29]);
#     PIX_SORT(p[14], p[30]); PIX_SORT(p[14], p[31]); PIX_SORT(p[14], p[32]);
#     PIX_SORT(p[14], p[33]); PIX_SORT(p[14], p[34]); PIX_SORT(p[14], p[35]);
#     PIX_SORT(p[14], p[36]); PIX_SORT(p[14], p[37]); PIX_SORT(p[14], p[38]);
#     PIX_SORT(p[14], p[39]); PIX_SORT(p[14], p[40]); PIX_SORT(p[14], p[41]);
#     PIX_SORT(p[14], p[42]); PIX_SORT(p[14], p[43]); PIX_SORT(p[14], p[44]);
#     PIX_SORT(p[14], p[45]); PIX_SORT(p[14], p[46]); PIX_SORT(p[14], p[47]);
#     PIX_SORT(p[14], p[48]); PIX_SORT(p[14], p[49]); PIX_SORT(p[14], p[50]);
#     PIX_SORT(p[14], p[51]); PIX_SORT(p[14], p[52]); PIX_SORT(p[14], p[53]);
#     PIX_SORT(p[14], p[54]); PIX_SORT(p[14], p[55]); PIX_SORT(p[14], p[56]);
#     PIX_SORT(p[14], p[57]); PIX_SORT(p[14], p[58]); PIX_SORT(p[14], p[59]);
#     PIX_SORT(p[14], p[60]); PIX_SORT(p[14], p[61]); PIX_SORT(p[14], p[62]);
#     PIX_SORT(p[14], p[63]); PIX_SORT(p[14], p[64]); PIX_SORT(p[14], p[65]);
#     PIX_SORT(p[14], p[66]); PIX_SORT(p[14], p[67]); PIX_SORT(p[14], p[68]);
#     PIX_SORT(p[14], p[69]); PIX_SORT(p[14], p[70]); PIX_SORT(p[14], p[71]);
#     PIX_SORT(p[14], p[72]); PIX_SORT(p[14], p[73]); PIX_SORT(p[14], p[74]);
#     PIX_SORT(p[14], p[75]); PIX_SORT(p[14], p[76]); PIX_SORT(p[14], p[77]);
#     PIX_SORT(p[14], p[78]); PIX_SORT(p[14], p[79]); PIX_SORT(p[14], p[80]);
#     PIX_SORT(p[15], p[16]); PIX_SORT(p[15], p[17]); PIX_SORT(p[15], p[18]);
#     PIX_SORT(p[15], p[19]); PIX_SORT(p[15], p[20]); PIX_SORT(p[15], p[21]);
#     PIX_SORT(p[15], p[22]); PIX_SORT(p[15], p[23]); PIX_SORT(p[15], p[24]);
#     PIX_SORT(p[15], p[25]); PIX_SORT(p[15], p[26]); PIX_SORT(p[15], p[27]);
#     PIX_SORT(p[15], p[28]); PIX_SORT(p[15], p[29]); PIX_SORT(p[15], p[30]);
#     PIX_SORT(p[15], p[31]); PIX_SORT(p[15], p[32]); PIX_SORT(p[15], p[33]);
#     PIX_SORT(p[15], p[34]); PIX_SORT(p[15], p[35]); PIX_SORT(p[15], p[36]);
#     PIX_SORT(p[15], p[37]); PIX_SORT(p[15], p[38]); PIX_SORT(p[15], p[39]);
#     PIX_SORT(p[15], p[40]); PIX_SORT(p[15], p[41]); PIX_SORT(p[15], p[42]);
#     PIX_SORT(p[15], p[43]); PIX_SORT(p[15], p[44]); PIX_SORT(p[15], p[45]);
#     PIX_SORT(p[15], p[46]); PIX_SORT(p[15], p[47]); PIX_SORT(p[15], p[48]);
#     PIX_SORT(p[15], p[49]); PIX_SORT(p[15], p[50]); PIX_SORT(p[15], p[51]);
#     PIX_SORT(p[15], p[52]); PIX_SORT(p[15], p[53]); PIX_SORT(p[15], p[54]);
#     PIX_SORT(p[15], p[55]); PIX_SORT(p[15], p[56]); PIX_SORT(p[15], p[57]);
#     PIX_SORT(p[15], p[58]); PIX_SORT(p[15], p[59]); PIX_SORT(p[15], p[60]);
#     PIX_SORT(p[15], p[61]); PIX_SORT(p[15], p[62]); PIX_SORT(p[15], p[63]);
#     PIX_SORT(p[15], p[64]); PIX_SORT(p[15], p[65]); PIX_SORT(p[15], p[66]);
#     PIX_SORT(p[15], p[67]); PIX_SORT(p[15], p[68]); PIX_SORT(p[15], p[69]);
#     PIX_SORT(p[15], p[70]); PIX_SORT(p[15], p[71]); PIX_SORT(p[15], p[72]);
#     PIX_SORT(p[15], p[73]); PIX_SORT(p[15], p[74]); PIX_SORT(p[15], p[75]);
#     PIX_SORT(p[15], p[76]); PIX_SORT(p[15], p[77]); PIX_SORT(p[15], p[78]);
#     PIX_SORT(p[15], p[79]); PIX_SORT(p[15], p[80]); PIX_SORT(p[16], p[17]);
#     PIX_SORT(p[16], p[18]); PIX_SORT(p[16], p[19]); PIX_SORT(p[16], p[20]);
#     PIX_SORT(p[16], p[21]); PIX_SORT(p[16], p[22]); PIX_SORT(p[16], p[23]);
#     PIX_SORT(p[16], p[24]); PIX_SORT(p[16], p[25]); PIX_SORT(p[16], p[26]);
#     PIX_SORT(p[16], p[27]); PIX_SORT(p[16], p[28]); PIX_SORT(p[16], p[29]);
#     PIX_SORT(p[16], p[30]); PIX_SORT(p[16], p[31]); PIX_SORT(p[16], p[32]);
#     PIX_SORT(p[16], p[33]); PIX_SORT(p[16], p[34]); PIX_SORT(p[16], p[35]);
#     PIX_SORT(p[16], p[36]); PIX_SORT(p[16], p[37]); PIX_SORT(p[16], p[38]);
#     PIX_SORT(p[16], p[39]); PIX_SORT(p[16], p[40]); PIX_SORT(p[16], p[41]);
#     PIX_SORT(p[16], p[42]); PIX_SORT(p[16], p[43]); PIX_SORT(p[16], p[44]);
#     PIX_SORT(p[16], p[45]); PIX_SORT(p[16], p[46]); PIX_SORT(p[16], p[47]);
#     PIX_SORT(p[16], p[48]); PIX_SORT(p[16], p[49]); PIX_SORT(p[16], p[50]);
#     PIX_SORT(p[16], p[51]); PIX_SORT(p[16], p[52]); PIX_SORT(p[16], p[53]);
#     PIX_SORT(p[16], p[54]); PIX_SORT(p[16], p[55]); PIX_SORT(p[16], p[56]);
#     PIX_SORT(p[16], p[57]); PIX_SORT(p[16], p[58]); PIX_SORT(p[16], p[59]);
#     PIX_SORT(p[16], p[60]); PIX_SORT(p[16], p[61]); PIX_SORT(p[16], p[62]);
#     PIX_SORT(p[16], p[63]); PIX_SORT(p[16], p[64]); PIX_SORT(p[16], p[65]);
#     PIX_SORT(p[16], p[66]); PIX_SORT(p[16], p[67]); PIX_SORT(p[16], p[68]);
#     PIX_SORT(p[16], p[69]); PIX_SORT(p[16], p[70]); PIX_SORT(p[16], p[71]);
#     PIX_SORT(p[16], p[72]); PIX_SORT(p[16], p[73]); PIX_SORT(p[16], p[74]);
#     PIX_SORT(p[16], p[75]); PIX_SORT(p[16], p[76]); PIX_SORT(p[16], p[77]);
#     PIX_SORT(p[16], p[78]); PIX_SORT(p[16], p[79]); PIX_SORT(p[16], p[80]);
#     PIX_SORT(p[17], p[18]); PIX_SORT(p[17], p[19]); PIX_SORT(p[17], p[20]);
#     PIX_SORT(p[17], p[21]); PIX_SORT(p[17], p[22]); PIX_SORT(p[17], p[23]);
#     PIX_SORT(p[17], p[24]); PIX_SORT(p[17], p[25]); PIX_SORT(p[17], p[26]);
#     PIX_SORT(p[17], p[27]); PIX_SORT(p[17], p[28]); PIX_SORT(p[17], p[29]);
#     PIX_SORT(p[17], p[30]); PIX_SORT(p[17], p[31]); PIX_SORT(p[17], p[32]);
#     PIX_SORT(p[17], p[33]); PIX_SORT(p[17], p[34]); PIX_SORT(p[17], p[35]);
#     PIX_SORT(p[17], p[36]); PIX_SORT(p[17], p[37]); PIX_SORT(p[17], p[38]);
#     PIX_SORT(p[17], p[39]); PIX_SORT(p[17], p[40]); PIX_SORT(p[17], p[41]);
#     PIX_SORT(p[17], p[42]); PIX_SORT(p[17], p[43]); PIX_SORT(p[17], p[44]);
#     PIX_SORT(p[17], p[45]); PIX_SORT(p[17], p[46]); PIX_SORT(p[17], p[47]);
#     PIX_SORT(p[17], p[48]); PIX_SORT(p[17], p[49]); PIX_SORT(p[17], p[50]);
#     PIX_SORT(p[17], p[51]); PIX_SORT(p[17], p[52]); PIX_SORT(p[17], p[53]);
#     PIX_SORT(p[17], p[54]); PIX_SORT(p[17], p[55]); PIX_SORT(p[17], p[56]);
#     PIX_SORT(p[17], p[57]); PIX_SORT(p[17], p[58]); PIX_SORT(p[17], p[59]);
#     PIX_SORT(p[17], p[60]); PIX_SORT(p[17], p[61]); PIX_SORT(p[17], p[62]);
#     PIX_SORT(p[17], p[63]); PIX_SORT(p[17], p[64]); PIX_SORT(p[17], p[65]);
#     PIX_SORT(p[17], p[66]); PIX_SORT(p[17], p[67]); PIX_SORT(p[17], p[68]);
#     PIX_SORT(p[17], p[69]); PIX_SORT(p[17], p[70]); PIX_SORT(p[17], p[71]);
#     PIX_SORT(p[17], p[72]); PIX_SORT(p[17], p[73]); PIX_SORT(p[17], p[74]);
#     PIX_SORT(p[17], p[75]); PIX_SORT(p[17], p[76]); PIX_SORT(p[17], p[77]);
#     PIX_SORT(p[17], p[78]); PIX_SORT(p[17], p[79]); PIX_SORT(p[17], p[80]);
#     PIX_SORT(p[18], p[19]); PIX_SORT(p[18], p[20]); PIX_SORT(p[18], p[21]);
#     PIX_SORT(p[18], p[22]); PIX_SORT(p[18], p[23]); PIX_SORT(p[18], p[24]);
#     PIX_SORT(p[18], p[25]); PIX_SORT(p[18], p[26]); PIX_SORT(p[18], p[27]);
#     PIX_SORT(p[18], p[28]); PIX_SORT(p[18], p[29]); PIX_SORT(p[18], p[30]);
#     PIX_SORT(p[18], p[31]); PIX_SORT(p[18], p[32]); PIX_SORT(p[18], p[33]);
#     PIX_SORT(p[18], p[34]); PIX_SORT(p[18], p[35]); PIX_SORT(p[18], p[36]);
#     PIX_SORT(p[18], p[37]); PIX_SORT(p[18], p[38]); PIX_SORT(p[18], p[39]);
#     PIX_SORT(p[18], p[40]); PIX_SORT(p[18], p[41]); PIX_SORT(p[18], p[42]);
#     PIX_SORT(p[18], p[43]); PIX_SORT(p[18], p[44]); PIX_SORT(p[18], p[45]);
#     PIX_SORT(p[18], p[46]); PIX_SORT(p[18], p[47]); PIX_SORT(p[18], p[48]);
#     PIX_SORT(p[18], p[49]); PIX_SORT(p[18], p[50]); PIX_SORT(p[18], p[51]);
#     PIX_SORT(p[18], p[52]); PIX_SORT(p[18], p[53]); PIX_SORT(p[18], p[54]);
#     PIX_SORT(p[18], p[55]); PIX_SORT(p[18], p[56]); PIX_SORT(p[18], p[57]);
#     PIX_SORT(p[18], p[58]); PIX_SORT(p[18], p[59]); PIX_SORT(p[18], p[60]);
#     PIX_SORT(p[18], p[61]); PIX_SORT(p[18], p[62]); PIX_SORT(p[18], p[63]);
#     PIX_SORT(p[18], p[64]); PIX_SORT(p[18], p[65]); PIX_SORT(p[18], p[66]);
#     PIX_SORT(p[18], p[67]); PIX_SORT(p[18], p[68]); PIX_SORT(p[18], p[69]);
#     PIX_SORT(p[18], p[70]); PIX_SORT(p[18], p[71]); PIX_SORT(p[18], p[72]);
#     PIX_SORT(p[18], p[73]); PIX_SORT(p[18], p[74]); PIX_SORT(p[18], p[75]);
#     PIX_SORT(p[18], p[76]); PIX_SORT(p[18], p[77]); PIX_SORT(p[18], p[78]);
#     PIX_SORT(p[18], p[79]); PIX_SORT(p[18], p[80]); PIX_SORT(p[19], p[20]);
#     PIX_SORT(p[19], p[21]); PIX_SORT(p[19], p[22]); PIX_SORT(p[19], p[23]);
#     PIX_SORT(p[19], p[24]); PIX_SORT(p[19], p[25]); PIX_SORT(p[19], p[26]);
#     PIX_SORT(p[19], p[27]); PIX_SORT(p[19], p[28]); PIX_SORT(p[19], p[29]);
#     PIX_SORT(p[19], p[30]); PIX_SORT(p[19], p[31]); PIX_SORT(p[19], p[32]);
#     PIX_SORT(p[19], p[33]); PIX_SORT(p[19], p[34]); PIX_SORT(p[19], p[35]);
#     PIX_SORT(p[19], p[36]); PIX_SORT(p[19], p[37]); PIX_SORT(p[19], p[38]);
#     PIX_SORT(p[19], p[39]); PIX_SORT(p[19], p[40]); PIX_SORT(p[19], p[41]);
#     PIX_SORT(p[19], p[42]); PIX_SORT(p[19], p[43]); PIX_SORT(p[19], p[44]);
#     PIX_SORT(p[19], p[45]); PIX_SORT(p[19], p[46]); PIX_SORT(p[19], p[47]);
#     PIX_SORT(p[19], p[48]); PIX_SORT(p[19], p[49]); PIX_SORT(p[19], p[50]);
#     PIX_SORT(p[19], p[51]); PIX_SORT(p[19], p[52]); PIX_SORT(p[19], p[53]);
#     PIX_SORT(p[19], p[54]); PIX_SORT(p[19], p[55]); PIX_SORT(p[19], p[56]);
#     PIX_SORT(p[19], p[57]); PIX_SORT(p[19], p[58]); PIX_SORT(p[19], p[59]);
#     PIX_SORT(p[19], p[60]); PIX_SORT(p[19], p[61]); PIX_SORT(p[19], p[62]);
#     PIX_SORT(p[19], p[63]); PIX_SORT(p[19], p[64]); PIX_SORT(p[19], p[65]);
#     PIX_SORT(p[19], p[66]); PIX_SORT(p[19], p[67]); PIX_SORT(p[19], p[68]);
#     PIX_SORT(p[19], p[69]); PIX_SORT(p[19], p[70]); PIX_SORT(p[19], p[71]);
#     PIX_SORT(p[19], p[72]); PIX_SORT(p[19], p[73]); PIX_SORT(p[19], p[74]);
#     PIX_SORT(p[19], p[75]); PIX_SORT(p[19], p[76]); PIX_SORT(p[19], p[77]);
#     PIX_SORT(p[19], p[78]); PIX_SORT(p[19], p[79]); PIX_SORT(p[19], p[80]);
#     PIX_SORT(p[20], p[21]); PIX_SORT(p[20], p[22]); PIX_SORT(p[20], p[23]);
#     PIX_SORT(p[20], p[24]); PIX_SORT(p[20], p[25]); PIX_SORT(p[20], p[26]);
#     PIX_SORT(p[20], p[27]); PIX_SORT(p[20], p[28]); PIX_SORT(p[20], p[29]);
#     PIX_SORT(p[20], p[30]); PIX_SORT(p[20], p[31]); PIX_SORT(p[20], p[32]);
#     PIX_SORT(p[20], p[33]); PIX_SORT(p[20], p[34]); PIX_SORT(p[20], p[35]);
#     PIX_SORT(p[20], p[36]); PIX_SORT(p[20], p[37]); PIX_SORT(p[20], p[38]);
#     PIX_SORT(p[20], p[39]); PIX_SORT(p[20], p[40]); PIX_SORT(p[20], p[41]);
#     PIX_SORT(p[20], p[42]); PIX_SORT(p[20], p[43]); PIX_SORT(p[20], p[44]);
#     PIX_SORT(p[20], p[45]); PIX_SORT(p[20], p[46]); PIX_SORT(p[20], p[47]);
#     PIX_SORT(p[20], p[48]); PIX_SORT(p[20], p[49]); PIX_SORT(p[20], p[50]);
#     PIX_SORT(p[20], p[51]); PIX_SORT(p[20], p[52]); PIX_SORT(p[20], p[53]);
#     PIX_SORT(p[20], p[54]); PIX_SORT(p[20], p[55]); PIX_SORT(p[20], p[56]);
#     PIX_SORT(p[20], p[57]); PIX_SORT(p[20], p[58]); PIX_SORT(p[20], p[59]);
#     PIX_SORT(p[20], p[60]); PIX_SORT(p[20], p[61]); PIX_SORT(p[20], p[62]);
#     PIX_SORT(p[20], p[63]); PIX_SORT(p[20], p[64]); PIX_SORT(p[20], p[65]);
#     PIX_SORT(p[20], p[66]); PIX_SORT(p[20], p[67]); PIX_SORT(p[20], p[68]);
#     PIX_SORT(p[20], p[69]); PIX_SORT(p[20], p[70]); PIX_SORT(p[20], p[71]);
#     PIX_SORT(p[20], p[72]); PIX_SORT(p[20], p[73]); PIX_SORT(p[20], p[74]);
#     PIX_SORT(p[20], p[75]); PIX_SORT(p[20], p[76]); PIX_SORT(p[20], p[77]);
#     PIX_SORT(p[20], p[78]); PIX_SORT(p[20], p[79]); PIX_SORT(p[20], p[80]);
#     PIX_SORT(p[21], p[22]); PIX_SORT(p[21], p[23]); PIX_SORT(p[21], p[24]);
#     PIX_SORT(p[21], p[25]); PIX_SORT(p[21], p[26]); PIX_SORT(p[21], p[27]);
#     PIX_SORT(p[21], p[28]); PIX_SORT(p[21], p[29]); PIX_SORT(p[21], p[30]);
#     PIX_SORT(p[21], p[31]); PIX_SORT(p[21], p[32]); PIX_SORT(p[21], p[33]);
#     PIX_SORT(p[21], p[34]); PIX_SORT(p[21], p[35]); PIX_SORT(p[21], p[36]);
#     PIX_SORT(p[21], p[37]); PIX_SORT(p[21], p[38]); PIX_SORT(p[21], p[39]);
#     PIX_SORT(p[21], p[40]); PIX_SORT(p[21], p[41]); PIX_SORT(p[21], p[42]);
#     PIX_SORT(p[21], p[43]); PIX_SORT(p[21], p[44]); PIX_SORT(p[21], p[45]);
#     PIX_SORT(p[21], p[46]); PIX_SORT(p[21], p[47]); PIX_SORT(p[21], p[48]);
#     PIX_SORT(p[21], p[49]); PIX_SORT(p[21], p[50]); PIX_SORT(p[21], p[51]);
#     PIX_SORT(p[21], p[52]); PIX_SORT(p[21], p[53]); PIX_SORT(p[21], p[54]);
#     PIX_SORT(p[21], p[55]); PIX_SORT(p[21], p[56]); PIX_SORT(p[21], p[57]);
#     PIX_SORT(p[21], p[58]); PIX_SORT(p[21], p[59]); PIX_SORT(p[21], p[60]);
#     PIX_SORT(p[21], p[61]); PIX_SORT(p[21], p[62]); PIX_SORT(p[21], p[63]);
#     PIX_SORT(p[21], p[64]); PIX_SORT(p[21], p[65]); PIX_SORT(p[21], p[66]);
#     PIX_SORT(p[21], p[67]); PIX_SORT(p[21], p[68]); PIX_SORT(p[21], p[69]);
#     PIX_SORT(p[21], p[70]); PIX_SORT(p[21], p[71]); PIX_SORT(p[21], p[72]);
#     PIX_SORT(p[21], p[73]); PIX_SORT(p[21], p[74]); PIX_SORT(p[21], p[75]);
#     PIX_SORT(p[21], p[76]); PIX_SORT(p[21], p[77]); PIX_SORT(p[21], p[78]);
#     PIX_SORT(p[21], p[79]); PIX_SORT(p[21], p[80]); PIX_SORT(p[22], p[23]);
#     PIX_SORT(p[22], p[24]); PIX_SORT(p[22], p[25]); PIX_SORT(p[22], p[26]);
#     PIX_SORT(p[22], p[27]); PIX_SORT(p[22], p[28]); PIX_SORT(p[22], p[29]);
#     PIX_SORT(p[22], p[30]); PIX_SORT(p[22], p[31]); PIX_SORT(p[22], p[32]);
#     PIX_SORT(p[22], p[33]); PIX_SORT(p[22], p[34]); PIX_SORT(p[22], p[35]);
#     PIX_SORT(p[22], p[36]); PIX_SORT(p[22], p[37]); PIX_SORT(p[22], p[38]);
#     PIX_SORT(p[22], p[39]); PIX_SORT(p[22], p[40]); PIX_SORT(p[22], p[41]);
#     PIX_SORT(p[22], p[42]); PIX_SORT(p[22], p[43]); PIX_SORT(p[22], p[44]);
#     PIX_SORT(p[22], p[45]); PIX_SORT(p[22], p[46]); PIX_SORT(p[22], p[47]);
#     PIX_SORT(p[22], p[48]); PIX_SORT(p[22], p[49]); PIX_SORT(p[22], p[50]);
#     PIX_SORT(p[22], p[51]); PIX_SORT(p[22], p[52]); PIX_SORT(p[22], p[53]);
#     PIX_SORT(p[22], p[54]); PIX_SORT(p[22], p[55]); PIX_SORT(p[22], p[56]);
#     PIX_SORT(p[22], p[57]); PIX_SORT(p[22], p[58]); PIX_SORT(p[22], p[59]);
#     PIX_SORT(p[22], p[60]); PIX_SORT(p[22], p[61]); PIX_SORT(p[22], p[62]);
#     PIX_SORT(p[22], p[63]); PIX_SORT(p[22], p[64]); PIX_SORT(p[22], p[65]);
#     PIX_SORT(p[22], p[66]); PIX_SORT(p[22], p[67]); PIX_SORT(p[22], p[68]);
#     PIX_SORT(p[22], p[69]); PIX_SORT(p[22], p[70]); PIX_SORT(p[22], p[71]);
#     PIX_SORT(p[22], p[72]); PIX_SORT(p[22], p[73]); PIX_SORT(p[22], p[74]);
#     PIX_SORT(p[22], p[75]); PIX_SORT(p[22], p[76]); PIX_SORT(p[22], p[77]);
#     PIX_SORT(p[22], p[78]); PIX_SORT(p[22], p[79]); PIX_SORT(p[22], p[80]);
#     PIX_SORT(p[23], p[24]); PIX_SORT(p[23], p[25]); PIX_SORT(p[23], p[26]);
#     PIX_SORT(p[23], p[27]); PIX_SORT(p[23], p[28]); PIX_SORT(p[23], p[29]);
#     PIX_SORT(p[23], p[30]); PIX_SORT(p[23], p[31]); PIX_SORT(p[23], p[32]);
#     PIX_SORT(p[23], p[33]); PIX_SORT(p[23], p[34]); PIX_SORT(p[23], p[35]);
#     PIX_SORT(p[23], p[36]); PIX_SORT(p[23], p[37]); PIX_SORT(p[23], p[38]);
#     PIX_SORT(p[23], p[39]); PIX_SORT(p[23], p[40]); PIX_SORT(p[23], p[41]);
#     PIX_SORT(p[23], p[42]); PIX_SORT(p[23], p[43]); PIX_SORT(p[23], p[44]);
#     PIX_SORT(p[23], p[45]); PIX_SORT(p[23], p[46]); PIX_SORT(p[23], p[47]);
#     PIX_SORT(p[23], p[48]); PIX_SORT(p[23], p[49]); PIX_SORT(p[23], p[50]);
#     PIX_SORT(p[23], p[51]); PIX_SORT(p[23], p[52]); PIX_SORT(p[23], p[53]);
#     PIX_SORT(p[23], p[54]); PIX_SORT(p[23], p[55]); PIX_SORT(p[23], p[56]);
#     PIX_SORT(p[23], p[57]); PIX_SORT(p[23], p[58]); PIX_SORT(p[23], p[59]);
#     PIX_SORT(p[23], p[60]); PIX_SORT(p[23], p[61]); PIX_SORT(p[23], p[62]);
#     PIX_SORT(p[23], p[63]); PIX_SORT(p[23], p[64]); PIX_SORT(p[23], p[65]);
#     PIX_SORT(p[23], p[66]); PIX_SORT(p[23], p[67]); PIX_SORT(p[23], p[68]);
#     PIX_SORT(p[23], p[69]); PIX_SORT(p[23], p[70]); PIX_SORT(p[23], p[71]);
#     PIX_SORT(p[23], p[72]); PIX_SORT(p[23], p[73]); PIX_SORT(p[23], p[74]);
#     PIX_SORT(p[23], p[75]); PIX_SORT(p[23], p[76]); PIX_SORT(p[23], p[77]);
#     PIX_SORT(p[23], p[78]); PIX_SORT(p[23], p[79]); PIX_SORT(p[23], p[80]);
#     PIX_SORT(p[24], p[25]); PIX_SORT(p[24], p[26]); PIX_SORT(p[24], p[27]);
#     PIX_SORT(p[24], p[28]); PIX_SORT(p[24], p[29]); PIX_SORT(p[24], p[30]);
#     PIX_SORT(p[24], p[31]); PIX_SORT(p[24], p[32]); PIX_SORT(p[24], p[33]);
#     PIX_SORT(p[24], p[34]); PIX_SORT(p[24], p[35]); PIX_SORT(p[24], p[36]);
#     PIX_SORT(p[24], p[37]); PIX_SORT(p[24], p[38]); PIX_SORT(p[24], p[39]);
#     PIX_SORT(p[24], p[40]); PIX_SORT(p[24], p[41]); PIX_SORT(p[24], p[42]);
#     PIX_SORT(p[24], p[43]); PIX_SORT(p[24], p[44]); PIX_SORT(p[24], p[45]);
#     PIX_SORT(p[24], p[46]); PIX_SORT(p[24], p[47]); PIX_SORT(p[24], p[48]);
#     PIX_SORT(p[24], p[49]); PIX_SORT(p[24], p[50]); PIX_SORT(p[24], p[51]);
#     PIX_SORT(p[24], p[52]); PIX_SORT(p[24], p[53]); PIX_SORT(p[24], p[54]);
#     PIX_SORT(p[24], p[55]); PIX_SORT(p[24], p[56]); PIX_SORT(p[24], p[57]);
#     PIX_SORT(p[24], p[58]); PIX_SORT(p[24], p[59]); PIX_SORT(p[24], p[60]);
#     PIX_SORT(p[24], p[61]); PIX_SORT(p[24], p[62]); PIX_SORT(p[24], p[63]);
#     PIX_SORT(p[24], p[64]); PIX_SORT(p[24], p[65]); PIX_SORT(p[24], p[66]);
#     PIX_SORT(p[24], p[67]); PIX_SORT(p[24], p[68]); PIX_SORT(p[24], p[69]);
#     PIX_SORT(p[24], p[70]); PIX_SORT(p[24], p[71]); PIX_SORT(p[24], p[72]);
#     PIX_SORT(p[24], p[73]); PIX_SORT(p[24], p[74]); PIX_SORT(p[24], p[75]);
#     PIX_SORT(p[24], p[76]); PIX_SORT(p[24], p[77]); PIX_SORT(p[24], p[78]);
#     PIX_SORT(p[24], p[79]); PIX_SORT(p[24], p[80]); PIX_SORT(p[25], p[26]);
#     PIX_SORT(p[25], p[27]); PIX_SORT(p[25], p[28]); PIX_SORT(p[25], p[29]);
#     PIX_SORT(p[25], p[30]); PIX_SORT(p[25], p[31]); PIX_SORT(p[25], p[32]);
#     PIX_SORT(p[25], p[33]); PIX_SORT(p[25], p[34]); PIX_SORT(p[25], p[35]);
#     PIX_SORT(p[25], p[36]); PIX_SORT(p[25], p[37]); PIX_SORT(p[25], p[38]);
#     PIX_SORT(p[25], p[39]); PIX_SORT(p[25], p[40]); PIX_SORT(p[25], p[41]);
#     PIX_SORT(p[25], p[42]); PIX_SORT(p[25], p[43]); PIX_SORT(p[25], p[44]);
#     PIX_SORT(p[25], p[45]); PIX_SORT(p[25], p[46]); PIX_SORT(p[25], p[47]);
#     PIX_SORT(p[25], p[48]); PIX_SORT(p[25], p[49]); PIX_SORT(p[25], p[50]);
#     PIX_SORT(p[25], p[51]); PIX_SORT(p[25], p[52]); PIX_SORT(p[25], p[53]);
#     PIX_SORT(p[25], p[54]); PIX_SORT(p[25], p[55]); PIX_SORT(p[25], p[56]);
#     PIX_SORT(p[25], p[57]); PIX_SORT(p[25], p[58]); PIX_SORT(p[25], p[59]);
#     PIX_SORT(p[25], p[60]); PIX_SORT(p[25], p[61]); PIX_SORT(p[25], p[62]);
#     PIX_SORT(p[25], p[63]); PIX_SORT(p[25], p[64]); PIX_SORT(p[25], p[65]);
#     PIX_SORT(p[25], p[66]); PIX_SORT(p[25], p[67]); PIX_SORT(p[25], p[68]);
#     PIX_SORT(p[25], p[69]); PIX_SORT(p[25], p[70]); PIX_SORT(p[25], p[71]);
#     PIX_SORT(p[25], p[72]); PIX_SORT(p[25], p[73]); PIX_SORT(p[25], p[74]);
#     PIX_SORT(p[25], p[75]); PIX_SORT(p[25], p[76]); PIX_SORT(p[25], p[77]);
#     PIX_SORT(p[25], p[78]); PIX_SORT(p[25], p[79]); PIX_SORT(p[25], p[80]);
#     PIX_SORT(p[26], p[27]); PIX_SORT(p[26], p[28]); PIX_SORT(p[26], p[29]);
#     PIX_SORT(p[26], p[30]); PIX_SORT(p[26], p[31]); PIX_SORT(p[26], p[32]);
#     PIX_SORT(p[26], p[33]); PIX_SORT(p[26], p[34]); PIX_SORT(p[26], p[35]);
#     PIX_SORT(p[26], p[36]); PIX_SORT(p[26], p[37]); PIX_SORT(p[26], p[38]);
#     PIX_SORT(p[26], p[39]); PIX_SORT(p[26], p[40]); PIX_SORT(p[26], p[41]);
#     PIX_SORT(p[26], p[42]); PIX_SORT(p[26], p[43]); PIX_SORT(p[26], p[44]);
#     PIX_SORT(p[26], p[45]); PIX_SORT(p[26], p[46]); PIX_SORT(p[26], p[47]);
#     PIX_SORT(p[26], p[48]); PIX_SORT(p[26], p[49]); PIX_SORT(p[26], p[50]);
#     PIX_SORT(p[26], p[51]); PIX_SORT(p[26], p[52]); PIX_SORT(p[26], p[53]);
#     PIX_SORT(p[26], p[54]); PIX_SORT(p[26], p[55]); PIX_SORT(p[26], p[56]);
#     PIX_SORT(p[26], p[57]); PIX_SORT(p[26], p[58]); PIX_SORT(p[26], p[59]);
#     PIX_SORT(p[26], p[60]); PIX_SORT(p[26], p[61]); PIX_SORT(p[26], p[62]);
#     PIX_SORT(p[26], p[63]); PIX_SORT(p[26], p[64]); PIX_SORT(p[26], p[65]);
#     PIX_SORT(p[26], p[66]); PIX_SORT(p[26], p[67]); PIX_SORT(p[26], p[68]);
#     PIX_SORT(p[26], p[69]); PIX_SORT(p[26], p[70]); PIX_SORT(p[26], p[71]);
#     PIX_SORT(p[26], p[72]); PIX_SORT(p[26], p[73]); PIX_SORT(p[26], p[74]);
#     PIX_SORT(p[26], p[75]); PIX_SORT(p[26], p[76]); PIX_SORT(p[26], p[77]);
#     PIX_SORT(p[26], p[78]); PIX_SORT(p[26], p[79]); PIX_SORT(p[26], p[80]);
#     PIX_SORT(p[27], p[28]); PIX_SORT(p[27], p[29]); PIX_SORT(p[27], p[30]);
#     PIX_SORT(p[27], p[31]); PIX_SORT(p[27], p[32]); PIX_SORT(p[27], p[33]);
#     PIX_SORT(p[27], p[34]); PIX_SORT(p[27], p[35]); PIX_SORT(p[27], p[36]);
#     PIX_SORT(p[27], p[37]); PIX_SORT(p[27], p[38]); PIX_SORT(p[27], p[39]);
#     PIX_SORT(p[27], p[40]); PIX_SORT(p[27], p[41]); PIX_SORT(p[27], p[42]);
#     PIX_SORT(p[27], p[43]); PIX_SORT(p[27], p[44]); PIX_SORT(p[27], p[45]);
#     PIX_SORT(p[27], p[46]); PIX_SORT(p[27], p[47]); PIX_SORT(p[27], p[48]);
#     PIX_SORT(p[27], p[49]); PIX_SORT(p[27], p[50]); PIX_SORT(p[27], p[51]);
#     PIX_SORT(p[27], p[52]); PIX_SORT(p[27], p[53]); PIX_SORT(p[27], p[54]);
#     PIX_SORT(p[27], p[55]); PIX_SORT(p[27], p[56]); PIX_SORT(p[27], p[57]);
#     PIX_SORT(p[27], p[58]); PIX_SORT(p[27], p[59]); PIX_SORT(p[27], p[60]);
#     PIX_SORT(p[27], p[61]); PIX_SORT(p[27], p[62]); PIX_SORT(p[27], p[63]);
#     PIX_SORT(p[27], p[64]); PIX_SORT(p[27], p[65]); PIX_SORT(p[27], p[66]);
#     PIX_SORT(p[27], p[67]); PIX_SORT(p[27], p[68]); PIX_SORT(p[27], p[69]);
#     PIX_SORT(p[27], p[70]); PIX_SORT(p[27], p[71]); PIX_SORT(p[27], p[72]);
#     PIX_SORT(p[27], p[73]); PIX_SORT(p[27], p[74]); PIX_SORT(p[27], p[75]);
#     PIX_SORT(p[27], p[76]); PIX_SORT(p[27], p[77]); PIX_SORT(p[27], p[78]);
#     PIX_SORT(p[27], p[79]); PIX_SORT(p[27], p[80]); PIX_SORT(p[28], p[29]);
#     PIX_SORT(p[28], p[30]); PIX_SORT(p[28], p[31]); PIX_SORT(p[28], p[32]);
#     PIX_SORT(p[28], p[33]); PIX_SORT(p[28], p[34]); PIX_SORT(p[28], p[35]);
#     PIX_SORT(p[28], p[36]); PIX_SORT(p[28], p[37]); PIX_SORT(p[28], p[38]);
#     PIX_SORT(p[28], p[39]); PIX_SORT(p[28], p[40]); PIX_SORT(p[28], p[41]);
#     PIX_SORT(p[28], p[42]); PIX_SORT(p[28], p[43]); PIX_SORT(p[28], p[44]);
#     PIX_SORT(p[28], p[45]); PIX_SORT(p[28], p[46]); PIX_SORT(p[28], p[47]);
#     PIX_SORT(p[28], p[48]); PIX_SORT(p[28], p[49]); PIX_SORT(p[28], p[50]);
#     PIX_SORT(p[28], p[51]); PIX_SORT(p[28], p[52]); PIX_SORT(p[28], p[53]);
#     PIX_SORT(p[28], p[54]); PIX_SORT(p[28], p[55]); PIX_SORT(p[28], p[56]);
#     PIX_SORT(p[28], p[57]); PIX_SORT(p[28], p[58]); PIX_SORT(p[28], p[59]);
#     PIX_SORT(p[28], p[60]); PIX_SORT(p[28], p[61]); PIX_SORT(p[28], p[62]);
#     PIX_SORT(p[28], p[63]); PIX_SORT(p[28], p[64]); PIX_SORT(p[28], p[65]);
#     PIX_SORT(p[28], p[66]); PIX_SORT(p[28], p[67]); PIX_SORT(p[28], p[68]);
#     PIX_SORT(p[28], p[69]); PIX_SORT(p[28], p[70]); PIX_SORT(p[28], p[71]);
#     PIX_SORT(p[28], p[72]); PIX_SORT(p[28], p[73]); PIX_SORT(p[28], p[74]);
#     PIX_SORT(p[28], p[75]); PIX_SORT(p[28], p[76]); PIX_SORT(p[28], p[77]);
#     PIX_SORT(p[28], p[78]); PIX_SORT(p[28], p[79]); PIX_SORT(p[28], p[80]);
# ...
#     PIX_SORT(p[45], p[46]); PIX_SORT(p[45], p[47]); PIX_SORT(p[45], p[48]);
#     PIX_SORT(p[45], p[49]); PIX_SORT(p[45], p[50]); PIX_SORT(p[45], p[51]);
#     PIX_SORT(p[45], p[52]); PIX_SORT(p[45], p[53]); PIX_SORT(p[45], p[54]);
#     PIX_SORT(p[45], p[55]); PIX_SORT(p[45], p[56]); PIX_SORT(p[45], p[57]);
#     PIX_SORT(p[45], p[58]); PIX_SORT(p[45], p[59]); PIX_SORT(p[45], p[60]);
#     PIX_SORT(p[45], p[61]); PIX_SORT(p[45], p[62]); PIX_SORT(p[45], p[63]);
#     PIX_SORT(p[45], p[64]); PIX_SORT(p[45], p[65]); PIX_SORT(p[45], p[66]);
#     PIX_SORT(p[45], p[67]); PIX_SORT(p[45], p[68]); PIX_SORT(p[45], p[69]);
#     PIX_SORT(p[45], p[70]); PIX_SORT(p[45], p[71]); PIX_SORT(p[45], p[72]);
#     PIX_SORT(p[45], p[73]); PIX_SORT(p[45], p[74]); PIX_SORT(p[45], p[75]);
#     PIX_SORT(p[45], p[76]); PIX_SORT(p[45], p[77]); PIX_SORT(p[45], p[78]);
#     PIX_SORT(p[45], p[79]); PIX_SORT(p[45], p[80]); PIX_SORT(p[46], p[47]);
#     PIX_SORT(p[46], p[48]); PIX_SORT(p[46], p[49]); PIX_SORT(p[46], p[50]);
#     PIX_SORT(p[46], p[51]); PIX_SORT(p[46], p[52]); PIX_SORT(p[46], p[53]);
#     PIX_SORT(p[46], p[54]); PIX_SORT(p[46], p[55]); PIX_SORT(p[46], p[56]);
#     PIX_SORT(p[46], p[57]); PIX_SORT(p[46], p[58]); PIX_SORT(p[46], p[59]);
#     PIX_SORT(p[46], p[60]); PIX_SORT(p[46], p[61]); PIX_SORT(p[46], p[62]);
#     PIX_SORT(p[46], p[63]); PIX_SORT(p[46], p[64]); PIX_SORT(p[46], p[65]);
#     PIX_SORT(p[46], p[66]); PIX_SORT(p[46], p[67]); PIX_SORT(p[46], p[68]);
#     PIX_SORT(p[46], p[69]); PIX_SORT(p[46], p[70]); PIX_SORT(p[46], p[71]);
#     PIX_SORT(p[46], p[72]); PIX_SORT(p[46], p[73]); PIX_SORT(p[46], p[74]);
#     PIX_SORT(p[46], p[75]); PIX_SORT(p[46], p[76]); PIX_SORT(p[46], p[77]);
#     PIX_SORT(p[46], p[78]); PIX_SORT(p[46], p[79]); PIX_SORT(p[46], p[80]);
#     PIX_SORT(p[47], p[48]); PIX_SORT(p[47], p[49]); PIX_SORT(p[47], p[50]);
#     PIX_SORT(p[47], p[51]); PIX_SORT(p[47], p[52]); PIX_SORT(p[47], p[53]);
#     PIX_SORT(p[47], p[54]); PIX_SORT(p[47], p[55]); PIX_SORT(p[47], p[56]);
#     PIX_SORT(p[47], p[57]); PIX_SORT(p[47], p[58]); PIX_SORT(p[47], p[59]);
#     PIX_SORT(p[47], p[60]); PIX_SORT(p[47], p[61]); PIX_SORT(p[47], p[62]);
#     PIX_SORT(p[47], p[63]); PIX_SORT(p[47], p[64]); PIX_SORT(p[47], p[65]);
#     PIX_SORT(p[47], p[66]); PIX_SORT(p[47], p[67]); PIX_SORT(p[47], p[68]);
#     PIX_SORT(p[47], p[69]); PIX_SORT(p[47], p[70]); PIX_SORT(p[47], p[71]);
#     PIX_SORT(p[47], p[72]); PIX_SORT(p[47], p[73]); PIX_SORT(p[47], p[74]);
#     PIX_SORT(p[47], p[75]); PIX_SORT(p[47], p[76]); PIX_SORT(p[47], p[77]);
#     PIX_SORT(p[47], p[78]); PIX_SORT(p[47], p[79]); PIX_SORT(p[47], p[80]);
#     PIX_SORT(p[48], p[49]); PIX_SORT(p[48], p[50]); PIX_SORT(p[48], p[51]);
#     PIX_SORT(p[48], p[52]); PIX_SORT(p[48], p[53]); PIX_SORT(p[48], p[54]);
#     PIX_SORT(p[48], p[55]); PIX_SORT(p[48], p[56]); PIX_SORT(p[48], p[57]);
#     PIX_SORT(p[48], p[58]); PIX_SORT(p[48], p[59]); PIX_SORT(p[48], p[60]);
#     PIX_SORT(p[48], p[61]); PIX_SORT(p[48], p[62]); PIX_SORT(p[48], p[63]);
#     PIX_SORT(p[48], p[64]); PIX_SORT(p[48], p[65]); PIX_SORT(p[48], p[66]);
#     PIX_SORT(p[48], p[67]); PIX_SORT(p[48], p[68]); PIX_SORT(p[48], p[69]);
#     PIX_SORT(p[48], p[70]); PIX_SORT(p[48], p[71]); PIX_SORT(p[48], p[72]);
#     PIX_SORT(p[48], p[73]); PIX_SORT(p[48], p[74]); PIX_SORT(p[48], p[75]);
#     PIX_SORT(p[48], p[76]); PIX_SORT(p[48], p[77]); PIX_SORT(p[48], p[78]);
#     PIX_SORT(p[48], p[79]); PIX_SORT(p[48], p[80]); PIX_SORT(p[49], p[50]);
#     PIX_SORT(p[49], p[51]); PIX_SORT(p[49], p[52]); PIX_SORT(p[49], p[53]);
#     PIX_SORT(p[49], p[54]); PIX_SORT(p[49], p[55]); PIX_SORT(p[49], p[56]);
#     PIX_SORT(p[49], p[57]); PIX_SORT(p[49], p[58]); PIX_SORT(p[49], p[59]);
#     PIX_SORT(p[49], p[60]); PIX_SORT(p[49], p[61]); PIX_SORT(p[49], p[62]);
#     PIX_SORT(p[49], p[63]); PIX_SORT(p[49], p[64]); PIX_SORT(p[49], p[65]);
#     PIX_SORT(p[49], p[66]); PIX_SORT(p[49], p[67]); PIX_SORT(p[49], p[68]);
#     PIX_SORT(p[49], p[69]); PIX_SORT(p[49], p[70]); PIX_SORT(p[49], p[71]);
#     PIX_SORT(p[49], p[72]); PIX_SORT(p[49], p[73]); PIX_SORT(p[49], p[74]);
#     PIX_SORT(p[49], p[75]); PIX_SORT(p[49], p[76]); PIX_SORT(p[49], p[77]);
#     PIX_SORT(p[49], p[78]); PIX_SORT(p[49], p[79]); PIX_SORT(p[49], p[80]);
#     PIX_SORT(p[50], p[51]); PIX_SORT(p[50], p[52]); PIX_SORT(p[50], p[53]);
#     PIX_SORT(p[50], p[54]); PIX_SORT(p[50], p[55]); PIX_SORT(p[50], p[56]);
#     PIX_SORT(p[50], p[57]); PIX_SORT(p[50], p[58]); PIX_SORT(p[50], p[59]);
#     PIX_SORT(p[50], p[60]); PIX_SORT(p[50], p[61]); PIX_SORT(p[50], p[62]);
#     PIX_SORT(p[50], p[63]); PIX_SORT(p[50], p[64]); PIX_SORT(p[50], p[65]);
#     PIX_SORT(p[50], p[66]); PIX_SORT(p[50], p[67]); PIX_SORT(p[50], p[68]);
#     PIX_SORT(p[50], p[69]); PIX_SORT(p[50], p[70]); PIX_SORT(p[50], p[71]);
#     PIX_SORT(p[50], p[72]); PIX_SORT(p[50], p[73]); PIX_SORT(p[50], p[74]);
#     PIX_SORT(p[50], p[75]); PIX_SORT(p[50], p[76]); PIX_SORT(p[50], p[77]);
#     PIX_SORT(p[50], p[78]); PIX_SORT(p[50], p[79]); PIX_SORT(p[50], p[80]);
#     PIX_SORT(p[51], p[52]); PIX_SORT(p[51], p[53]); PIX_SORT(p[51], p[54]);
#     PIX_SORT(p[51], p[55]); PIX_SORT(p[51], p[56]); PIX_SORT(p[51], p[57]);
#     PIX_SORT(p[51], p[58]); PIX_SORT(p[51], p[59]); PIX_SORT(p[51], p[60]);
#     PIX_SORT(p[51], p[61]); PIX_SORT(p[51], p[62]); PIX_SORT(p[51], p[63]);
#     PIX_SORT(p[51], p[64]); PIX_SORT(p[51], p[65]); PIX_SORT(p[51], p[66]);
#     PIX_SORT(p[51], p[67]); PIX_SORT(p[51], p[68]); PIX_SORT(p[51], p[69]);
#     PIX_SORT(p[51], p[70]); PIX_SORT(p[51], p[71]); PIX_SORT(p[51], p[72]);
#     PIX_SORT(p[51], p[73]); PIX_SORT(p[51], p[74]); PIX_SORT(p[51], p[75]);
#     PIX_SORT(p[51], p[76]); PIX_SORT(p[51], p[77]); PIX_SORT(p[51], p[78]);
#     PIX_SORT(p[51], p[79]); PIX_SORT(p[51], p[80]); PIX_SORT(p[52], p[53]);
#     PIX_SORT(p[52], p[54]); PIX_SORT(p[52], p[55]); PIX_SORT(p[52], p[56]);
#     PIX_SORT(p[52], p[57]); PIX_SORT(p[52], p[58]); PIX_SORT(p[52], p[59]);
#     PIX_SORT(p[52], p[60]); PIX_SORT(p[52], p[61]); PIX_SORT(p[52], p[62]);
#     PIX_SORT(p[52], p[63]); PIX_SORT(p[52], p[64]); PIX_SORT(p[52], p[65]);
#     PIX_SORT(p[52], p[66]); PIX_SORT(p[52], p[67]); PIX_SORT(p[52], p[68]);
#     PIX_SORT(p[52], p[69]); PIX_SORT(p[52], p[70]); PIX_SORT(p[52], p[71]);
#     PIX_SORT(p[52], p[72]); PIX_SORT(p[52], p[73]); PIX_SORT(p[52], p[74]);
#     PIX_SORT(p[52], p[75]); PIX_SORT(p[52], p[76]); PIX_SORT(p[52], p[77]);
#     PIX_SORT(p[52], p[78]); PIX_SORT(p[52], p[79]); PIX_SORT(p[52], p[80]);
#     PIX_SORT(p[53], p[54]); PIX_SORT(p[53], p[55]); PIX_SORT(p[53], p[56]);
#     PIX_SORT(p[53], p[57]); PIX_SORT(p[53], p[58]); PIX_SORT(p[53], p[59]);
#     PIX_SORT(p[53], p[60]); PIX_SORT(p[53], p[61]); PIX_SORT(p[53], p[62]);
#     PIX_SORT(p[53], p[63]); PIX_SORT(p[53], p[64]); PIX_SORT(p[53], p[65]);
#     PIX_SORT(p[53], p[66]); PIX_SORT(p[53], p[67]); PIX_SORT(p[53], p[68]);
#     PIX_SORT(p[53], p[69]); PIX_SORT(p[53], p[70]); PIX_SORT(p[53], p[71]);
#     PIX_SORT(p[53], p[72]); PIX_SORT(p[53], p[73]); PIX_SORT(p[53], p[74]);
#     PIX_SORT(p[53], p[75]); PIX_SORT(p[53], p[76]); PIX_SORT(p[53], p[77]);
#     PIX_SORT(p[53], p[78]); PIX_SORT(p[53], p[79]); PIX_SORT(p[53], p[80]);
#     PIX_SORT(p[54], p[55]); PIX_SORT(p[54], p[56]); PIX_SORT(p[54], p[57]);
#     PIX_SORT(p[54], p[58]); PIX_SORT(p[54], p[59]); PIX_SORT(p[54], p[60]);
#     PIX_SORT(p[54], p[61]); PIX_SORT(p[54], p[62]); PIX_SORT(p[54], p[63]);
#     PIX_SORT(p[54], p[64]); PIX_SORT(p[54], p[65]); PIX_SORT(p[54], p[66]);
#     PIX_SORT(p[54], p[67]); PIX_SORT(p[54], p[68]); PIX_SORT(p[54], p[69]);
#     PIX_SORT(p[54], p[70]); PIX_SORT(p[54], p[71]); PIX_SORT(p[54], p[72]);
#     PIX_SORT(p[54], p[73]); PIX_SORT(p[54], p[74]); PIX_SORT(p[54], p[75]);
#     PIX_SORT(p[54], p[76]); PIX_SORT(p[54], p[77]); PIX_SORT(p[54], p[78]);
#     PIX_SORT(p[54], p[79]); PIX_SORT(p[54], p[80]); PIX_SORT(p[55], p[56]);
#     PIX_SORT(p[55], p[57]); PIX_SORT(p[55], p[58]); PIX_SORT(p[55], p[59]);
#     PIX_SORT(p[55], p[60]); PIX_SORT(p[55], p[61]); PIX_SORT(p[55], p[62]);
#     PIX_SORT(p[55], p[63]); PIX_SORT(p[55], p[64]); PIX_SORT(p[55], p[65]);
#     PIX_SORT(p[55], p[66]); PIX_SORT(p[55], p[67]); PIX_SORT(p[55], p[68]);
#     PIX_SORT(p[55], p[69]); PIX_SORT(p[55], p[70]); PIX_SORT(p[55], p[71]);
#     PIX_SORT(p[55], p[72]); PIX_SORT(p[55], p[73]); PIX_SORT(p[55], p[74]);
#     PIX_SORT(p[55], p[75]); PIX_SORT(p[55], p[76]); PIX_SORT(p[55], p[77]);
#     PIX_SORT(p[55], p[78]); PIX_SORT(p[55], p[79]); PIX_SORT(p[55], p[80]);
#     PIX_SORT(p[56], p[57]); PIX_SORT(p[56], p[58]); PIX_SORT(p[56], p[59]);
#     PIX_SORT(p[56], p[60]); PIX_SORT(p[56], p[61]); PIX_SORT(p[56], p[62]);
#     PIX_SORT(p[56], p[63]); PIX_SORT(p[56], p[64]); PIX_SORT(p[56], p[65]);
#     PIX_SORT(p[56], p[66]); PIX_SORT(p[56], p[67]); PIX_SORT(p[56], p[68]);
#     PIX_SORT(p[56], p[69]); PIX_SORT(p[56], p[70]); PIX_SORT(p[56], p[71]);
#     PIX_SORT(p[56], p[72]); PIX_SORT(p[56], p[73]); PIX_SORT(p[56], p[74]);
#     PIX_SORT(p[56], p[75]); PIX_SORT(p[56], p[76]); PIX_SORT(p[56], p[77]);
#     PIX_SORT(p[56], p[78]); PIX_SORT(p[56], p[79]); PIX_SORT(p[56], p[80]);
#     PIX_SORT(p[57], p[58]); PIX_SORT(p[57], p[59]); PIX_SORT(p[57], p[60]);
#     PIX_SORT(p[57], p[61]); PIX_SORT(p[57], p[62]); PIX_SORT(p[57], p[63]);
#     PIX_SORT(p[57], p[64]); PIX_SORT(p[57], p[65]); PIX_SORT(p[57], p[66]);
#     PIX_SORT(p[57], p[67]); PIX_SORT(p[57], p[68]); PIX_SORT(p[57], p[69]);
#     PIX_SORT(p[57], p[70]); PIX_SORT(p[57], p[71]); PIX_SORT(p[57], p[72]);
#     PIX_SORT(p[57], p[73]); PIX_SORT(p[57], p[74]); PIX_SORT(p[57], p[75]);
#     PIX_SORT(p[57], p[76]); PIX_SORT(p[57], p[77]); PIX_SORT(p[57], p[78]);
#     PIX_SORT(p[57], p[79]); PIX_SORT(p[57], p[80]); PIX_SORT(p[58], p[59]);
#     PIX_SORT(p[58], p[60]); PIX_SORT(p[58], p[61]); PIX_SORT(p[58], p[62]);
#     PIX_SORT(p[58], p[63]); PIX_SORT(p[58], p[64]); PIX_SORT(p[58], p[65]);
#     PIX_SORT(p[58], p[66]); PIX_SORT(p[58], p[67]); PIX_SORT(p[58], p[68]);
#     PIX_SORT(p[58], p[69]); PIX_SORT(p[58], p[70]); PIX_SORT(p[58], p[71]);
#     PIX_SORT(p[58], p[72]); PIX_SORT(p[58], p[73]); PIX_SORT(p[58], p[74]);
#     PIX_SORT(p[58], p[75]); PIX_SORT(p[58], p[76]); PIX_SORT(p[58], p[77]);
#     PIX_SORT(p[58], p[78]); PIX_SORT(p[58], p[79]); PIX_SORT(p[58], p[80]);
#     PIX_SORT(p[59], p[60]); PIX_SORT(p[59], p[61]); PIX_SORT(p[59], p[62]);
#     PIX_SORT(p[59], p[63]); PIX_SORT(p[59], p[64]); PIX_SORT(p[59], p[65]);
#     PIX_SORT(p[59], p[66]); PIX_SORT(p[59], p[67]); PIX_SORT(p[59], p[68]);
#     PIX_SORT(p[59], p[69]); PIX_SORT(p[59], p[70]); PIX_SORT(p[59], p[71]);
#     PIX_SORT(p[59], p[72]); PIX_SORT(p[59], p[73]); PIX_SORT(p[59], p[74]);
#     PIX_SORT(p[59], p[75]); PIX_SORT(p[59], p[76]); PIX_SORT(p[59], p[77]);
#     PIX_SORT(p[59], p[78]); PIX_SORT(p[59], p[79]); PIX_SORT(p[59], p[80]);
#     PIX_SORT(p[60], p[61]); PIX_SORT(p[60], p[62]); PIX_SORT(p[60], p[63]);
#     PIX_SORT(p[60], p[64]); PIX_SORT(p[60], p[65]); PIX_SORT(p[60], p[66]);
#     PIX_SORT(p[60], p[67]); PIX_SORT(p[60], p[68]); PIX_SORT(p[60], p[69]);
#     PIX_SORT(p[60], p[70]); PIX_SORT(p[60], p[71]); PIX_SORT(p[60], p[72]);
#     PIX_SORT(p[60], p[73]); PIX_SORT(p[60], p[74]); PIX_SORT(p[60], p[75]);
#     PIX_SORT(p[60], p[76]); PIX_SORT(p[60], p[77]); PIX_SORT(p[60], p[78]);
#     PIX_SORT(p[60], p[79]); PIX_SORT(p[60], p[80]); PIX_SORT(p[61], p[62]);
#     PIX_SORT(p[61], p[63]); PIX_SORT(p[61], p[64]); PIX_SORT(p[61], p[65]);
#     PIX_SORT(p[61], p[66]); PIX_SORT(p[61], p[67]); PIX_SORT(p[61], p[68]);
#     PIX_SORT(p[61], p[69]); PIX_SORT(p[61], p[70]); PIX_SORT(p[61], p[71]);
#     PIX_SORT(p[61], p[72]); PIX_SORT(p[61], p[73]); PIX_SORT(p[61], p[74]);
#     PIX_SORT(p[61], p[75]); PIX_SORT(p[61], p[76]); PIX_SORT(p[61], p[77]);
#     PIX_SORT(p[61], p[78]); PIX_SORT(p[61], p[79]); PIX_SORT(p[61], p[80]);
#     PIX_SORT(p[62], p[63]); PIX_SORT(p[62], p[64]); PIX_SORT(p[62], p[65]);
#     PIX_SORT(p[62], p[66]); PIX_SORT(p[62], p[67]); PIX_SORT(p[62], p[68]);
#     PIX_SORT(p[62], p[69]); PIX_SORT(p[62], p[70]); PIX_SORT(p[62], p[71]);
#     PIX_SORT(p[62], p[72]); PIX_SORT(p[62], p[73]); PIX_SORT(p[62], p[74]);
#     PIX_SORT(p[62], p[75]); PIX_SORT(p[62], p[76]); PIX_SORT(p[62], p[77]);
#     PIX_SORT(p[62], p[78]); PIX_SORT(p[62], p[79]); PIX_SORT(p[62], p[80]);
#     PIX_SORT(p[63], p[64]); PIX_SORT(p[63], p[65]); PIX_SORT(p[63], p[66]);
#     PIX_SORT(p[63], p[67]); PIX_SORT(p[63], p[68]); PIX_SORT(p[63], p[69]);
#     PIX_SORT(p[63], p[70]); PIX_SORT(p[63], p[71]); PIX_SORT(p[63], p[72]);
#     PIX_SORT(p[63], p[73]); PIX_SORT(p[63], p[74]); PIX_SORT(p[63], p[75]);
#     PIX_SORT(p[63], p[76]); PIX_SORT(p[63], p[77]); PIX_SORT(p[63], p[78]);
#     PIX_SORT(p[63], p[79]); PIX_SORT(p[63], p[80]); PIX_SORT(p[64], p[65]);
#     PIX_SORT(p[64], p[66]); PIX_SORT(p[64], p[67]); PIX_SORT(p[64], p[68]);
#     PIX_SORT(p[64], p[69]); PIX_SORT(p[64], p[70]); PIX_SORT(p[64], p[71]);
#     PIX_SORT(p[64], p[72]); PIX_SORT(p[64], p[73]); PIX_SORT(p[64], p[74]);
#     PIX_SORT(p[64], p[75]); PIX_SORT(p[64], p[76]); PIX_SORT(p[64], p[77]);
#     PIX_SORT(p[64], p[78]); PIX_SORT(p[64], p[79]); PIX_SORT(p[64], p[80]);
#     PIX_SORT(p[65], p[66]); PIX_SORT(p[65], p[67]); PIX_SORT(p[65], p[68]);
#     PIX_SORT(p[65], p[69]); PIX_SORT(p[65], p[70]); PIX_SORT(p[65], p[71]);
#     PIX_SORT(p[65], p[72]); PIX_SORT(p[65], p[73]); PIX_SORT(p[65], p[74]);
#     PIX_SORT(p[65], p[75]); PIX_SORT(p[65], p[76]); PIX_SORT(p[65], p[77]);
#     PIX_SORT(p[65], p[78]); PIX_SORT(p[65], p[79]); PIX_SORT(p[65], p[80]);
#     PIX_SORT(p[66], p[67]); PIX_SORT(p[66], p[68]); PIX_SORT(p[66], p[69]);
#     PIX_SORT(p[66], p[70]); PIX_SORT(p[66], p[71]); PIX_SORT(p[66], p[72]);
#     PIX_SORT(p[66], p[73]); PIX_SORT(p[66], p[74]); PIX_SORT(p[66], p[75]);
#     PIX_SORT(p[66], p[76]); PIX_SORT(p[66], p[77]); PIX_SORT(p[66], p[78]);
#     PIX_SORT(p[66], p[79]); PIX_SORT(p[66], p[80]); PIX_SORT(p[67], p[68]);
#     PIX_SORT(p[67], p[69]); PIX_SORT(p[67], p[70]); PIX_SORT(p[67], p[71]);
#     PIX_SORT(p[67], p[72]); PIX_SORT(p[67], p[73]); PIX_SORT(p[67], p[74]);
#     PIX_SORT(p[67], p[75]); PIX_SORT(p[67], p[76]); PIX_SORT(p[67], p[77]);
#     PIX_SORT(p[67], p[78]); PIX_SORT(p[67], p[79]); PIX_SORT(p[67], p[80]);
#     PIX_SORT(p[68], p[69]); PIX_SORT(p[68], p[70]); PIX_SORT(p[68], p[71]);
#     PIX_SORT(p[68], p[72]); PIX_SORT(p[68], p[73]); PIX_SORT(p[68], p[74]);
#     PIX_SORT(p[68], p[75]); PIX_SORT(p[68], p[76]); PIX_SORT(p[68], p[77]);
#     PIX_SORT(p[68], p[78]); PIX_SORT(p[68], p[79]); PIX_SORT(p[68], p[80]);
#     PIX_SORT(p[69], p[70]); PIX_SORT(p[69], p[71]); PIX_SORT(p[69], p[72]);
#     PIX_SORT(p[69], p[73]); PIX_SORT(p[69], p[74]); PIX_SORT(p[69], p[75]);
#     PIX_SORT(p[69], p[76]); PIX_SORT(p[69], p[77]); PIX_SORT(p[69], p[78]);
#     PIX_SORT(p[69], p[79]); PIX_SORT(p[69], p[80]); PIX_SORT(p[70], p[71]);
#     PIX_SORT(p[70], p[72]); PIX_SORT(p[70], p[73]); PIX_SORT(p[70], p[74]);
#     PIX_SORT(p[70], p[75]); PIX_SORT(p[70], p[76]); PIX_SORT(p[70], p[77]);
#     PIX_SORT(p[70], p[78]); PIX_SORT(p[70], p[79]); PIX_SORT(p[70], p[80]);
#     PIX_SORT(p[71], p[72]); PIX_SORT(p[71], p[73]); PIX_SORT(p[71], p[74]);
#     PIX_SORT(p[71], p[75]); PIX_SORT(p[71], p[76]); PIX_SORT(p[71], p[77]);
#     PIX_SORT(p[71], p[78]); PIX_SORT(p[71], p[79]); PIX_SORT(p[71], p[80]);
#     PIX_SORT(p[72], p[73]); PIX_SORT(p[72], p[74]); PIX_SORT(p[72], p[75]);
#     PIX_SORT(p[72], p[76]); PIX_SORT(p[72], p[77]); PIX_SORT(p[72], p[78]);
#     PIX_SORT(p[72], p[79]); PIX_SORT(p[72], p[80]); PIX_SORT(p[73], p[74]);
#     PIX_SORT(p[73], p[75]); PIX_SORT(p[73], p[76]); PIX_SORT(p[73], p[77]);
#     PIX_SORT(p[73], p[78]); PIX_SORT(p[73], p[79]); PIX_SORT(p[73], p[80]);
#     PIX_SORT(p[74], p[75]); PIX_SORT(p[74], p[76]); PIX_SORT(p[74], p[77]);
#     PIX_SORT(p[74], p[78]); PIX_SORT(p[74], p[79]); PIX_SORT(p[74], p[80]);
#     PIX_SORT(p[75], p[76]); PIX_SORT(p[75], p[77]); PIX_SORT(p[75], p[78]);
#     PIX_SORT(p[75], p[79]); PIX_SORT(p[75], p[80]); PIX_SORT(p[76], p[77]);
#     PIX_SORT(p[76], p[78]); PIX_SORT(p[76], p[79]); PIX_SORT(p[76], p[80]);
#     PIX_SORT(p[77], p[78]); PIX_SORT(p[77], p[79]); PIX_SORT(p[77], p[80]);
#     PIX_SORT(p[78], p[79]); PIX_SORT(p[78], p[80]); PIX_SORT(p[79], p[80]);
#     return p[40];
# }
